# %%
import requests
import re
from bs4 import BeautifulSoup

# %%
modern_front_page = requests.get('http://mtgtop8.com/format?f=MO&meta=44')

modern_front_page.status_code
# Out:
# 200

# %%
modern_front_page_soup = BeautifulSoup(modern_front_page.content, 'html.parser')

# %%
event_list = [event['href'] for event in modern_front_page_soup.find_all('table')[2].find('td').find_next_sibling().find_all('table')[1].find_all('a')]

# %%
event_list
# Out:
# ['event?e=18029&f=MO',
#  'event?e=18013&f=MO',
#  'event?e=18012&f=MO',
#  'event?e=17981&f=MO',
#  'event?e=18011&f=MO',
#  'event?e=18008&f=MO',
#  'event?e=18010&f=MO',
#  'event?e=18009&f=MO',
#  'event?e=17986&f=MO',
#  'event?e=17964&f=MO']

# %%
event_ids = list(map(lambda x: re.search("e=(\d+)&", x).group(1), event_list))

# %%
event_ids
# Out:
# ['18029',
#  '18013',
#  '18012',
#  '17981',
#  '18011',
#  '18008',
#  '18010',
#  '18009',
#  '17986',
#  '17964']

# %%
modern_event = requests.get('http://mtgtop8.com/event?e={}'.format(event_ids[0]))

modern_event.status_code
# Out:
# 200

# %%
modern_event_soup = BeautifulSoup(modern_event.content, 'html.parser'
# Out:
#   File "<ipython-input-101-d223222ee88c>", line 1
#     type(modern_event_soup = BeautifulSoup(modern_event.content, 'html.parser')
#                                                                                ^
# SyntaxError: unexpected EOF while parsing

# %%
modern_event_soup.find_all('table')[3].find_all('a')
# Out:
# [<a href="http://magic.wizards.com/en/articles/archive/mtgo-standings/competitive-modern-constructed-league-2018-01-03" target="_blank">http://magic.wizards.com/en/articles/archive/mtgo-...</a>,
#  <a class="topic" href="?e=18029&amp;d=311859&amp;f=MO">Eldrazi Aggro</a>,
#  <a class="topic" href="search?player=ManuGodineau">ManuGodineau</a>,
#  <a href="?e=18029&amp;d=311860&amp;f=MO">Hatebear</a>,
#  <a class="player" href="search?player=Randerson1">Randerson1</a>,
#  <a href="?e=18029&amp;d=311858&amp;f=MO">UR Storm</a>,
#  <a class="player" href="search?player=Pcyco">Pcyco</a>,
#  <a href="?e=18029&amp;d=311861&amp;f=MO">The Rock</a>,
#  <a class="player" href="search?player=triosk">triosk</a>,
#  <a href="?e=18029&amp;d=311862&amp;f=MO">Ad Nauseam</a>,
#  <a class="player" href="search?player=Zapgaze">Zapgaze</a>,
#  <a href="mtgo?d=311859&amp;f=Modern_Eldrazi_Aggro_by_ManuGodineau">MTGO</a>,
#  <a href="dec?d=311859&amp;f=Modern_Eldrazi_Aggro_by_ManuGodineau">.dec</a>,
# ...

# %%
deck_lists = modern_event_soup.find_all('table')[3].find_all('a')

# %%
# the [:-2] gets rid of the last two links, which are the download links for the highlighted deck list
deck_lists = list(filter(lambda x: 'd=' in x['href'], deck_lists))[:-2]

deck_lists
# Out:
# [<a class="topic" href="?e=18029&amp;d=311859&amp;f=MO">Eldrazi Aggro</a>,
#  <a href="?e=18029&amp;d=311860&amp;f=MO">Hatebear</a>,
#  <a href="?e=18029&amp;d=311858&amp;f=MO">UR Storm</a>,
#  <a href="?e=18029&amp;d=311861&amp;f=MO">The Rock</a>,
#  <a href="?e=18029&amp;d=311862&amp;f=MO">Ad Nauseam</a>]

# %%
deck_ids = list(map(lambda x: re.search("d=(\d+)&", x['href']).group(1), deck_lists))

deck_ids
# Out:
# ['311859', '311860', '311858', '311861', '311862']

# %%
mtg_deck_list = requests.get('http://mtgtop8.com/mtgo?d={}'.format(deck_ids[0]))

mtg_deck_list.status_code
# Out:
# 200

# %%
deck_list = mtg_deck_list.content

deck_list
# Out:
# b"4 Eldrazi Displacer\r\n4 Drowner of Hope\r\n3 Yavimaya Coast\r\n2 Windswept Heath\r\n1 Temple Garden\r\n1 Plains\r\n2 Misty Rainforest\r\n1 Island\r\n1 Hallowed Fountain\r\n1 Forest\r\n4 Eldrazi Temple\r\n4 Cavern of Souls\r\n3 Brushland\r\n1 Breeding Pool\r\n4 Engineered Explosives\r\n4 Ancient Stirrings\r\n4 Thought-Knot Seer\r\n4 Reality Smasher\r\n4 Noble Hierarch\r\n4 Matter Reshaper\r\n4 Eldrazi Skyspawner\r\nSideboard\r\n4 Stubborn Denial\r\n1 Rest in Peace\r\n4 Relic of Progenitus\r\n4 Reflector Mage\r\n1 Grafdigger's Cage\r\n1 Chalice of the Void\r\n"

# %%
deck_list.decode().split('\r\n')
# Out:
# ['4 Eldrazi Displacer',
#  '4 Drowner of Hope',
#  '3 Yavimaya Coast',
#  '2 Windswept Heath',
#  '1 Temple Garden',
#  '1 Plains',
#  '2 Misty Rainforest',
#  '1 Island',
#  '1 Hallowed Fountain',
#  '1 Forest',
#  '4 Eldrazi Temple',
#  '4 Cavern of Souls',
#  '3 Brushland',
#  '1 Breeding Pool',
#  '4 Engineered Explosives',
#  '4 Ancient Stirrings',
#  '4 Thought-Knot Seer',
#  '4 Reality Smasher',
#  '4 Noble Hierarch',
#  '4 Matter Reshaper',
#  '4 Eldrazi Skyspawner',
#  'Sideboard',
#  '4 Stubborn Denial',
#  '1 Rest in Peace',
#  '4 Relic of Progenitus',
#  '4 Reflector Mage',
#  "1 Grafdigger's Cage",
#  '1 Chalice of the Void',
#  '']

# %%
# used to read all the modern cards from 
import json

# %%
modern_legal_cards = requests.get('https://api.deckbrew.com/mtg/cards?format=modern')

modern_legal_cards.status_code
# Out:
# 200

# %%
modern_legal_cards.content.decode()
# Out:
# '[\n  {\n    "name": "Abandoned Sarcophagus",\n    "id": "abandoned-sarcophagus",\n    "url": "https://api.deckbrew.com/mtg/cards/abandoned-sarcophagus",\n    "store_url": "http://store.tcgplayer.com/magic/hour-of-devastation/abandoned-sarcophagus?partner=DECKBREW",\n    "types": [\n      "artifact"\n    ],\n    "cmc": 3,\n    "cost": "{3}",\n    "text": "You may cast nonland cards with cycling from your graveyard.\\nIf a card with cycling would be put into your graveyard from anywhere and it wasn\'t cycled, exile it instead.",\n    "formats": {\n      "commander": "legal",\n      "legacy": "legal",\n      "modern": "legal",\n      "standard": "legal",\n      "vintage": "legal"\n    },\n    "editions": [\n      {\n        "set": "Hour of Devastation",\n        "set_id": "HOU",\n        "rarity": "rare",\n        "artist": "Daarken",\n        "multiverse_id": 430847,\n        "flavor": "Although long since dead, the banished dissenters finally took their vengeance.",\n        "number"
# ...
