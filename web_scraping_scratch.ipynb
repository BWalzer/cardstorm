# %% [markdown]
# # Scraping Training Deck Lists

# %%
import requests
import re
import time # needed to wait between requests
import random # needed to wait random time between requests
from bs4 import BeautifulSoup

# %%
# send an http request to mtgtop8.com for their modern page. f=MO specifies the modern format and meta=44 is all decks
modern_front_page = requests.get('http://mtgtop8.com/format?f=MO&meta=44')

modern_front_page.status_code
# Out:
# 200

# %%
# put the html into a BeautifulSoup object to get anchors for each of the 'Last 10 Events'
modern_front_page_soup = BeautifulSoup(modern_front_page.content, 'html.parser')

event_list = [event['href'] for event in modern_front_page_soup.find_all('table')[2]
                  .find('td').find_next_sibling().find_all('table')[1].find_all('a')]

event_list
# Out:
# ['event?e=18048&f=MO',
#  'event?e=18038&f=MO',
#  'event?e=18037&f=MO',
#  'event?e=18029&f=MO',
#  'event?e=18013&f=MO',
#  'event?e=18012&f=MO',
#  'event?e=17981&f=MO',
#  'event?e=18011&f=MO',
#  'event?e=18008&f=MO',
#  'event?e=18010&f=MO']

# %%
# use map() and regular expressions to get the event id out of the anchor tags
event_ids = list(map(lambda x: re.search("e=(\d+)&", x).group(1), event_list))

event_ids
# Out:
# ['18048',
#  '18038',
#  '18037',
#  '18029',
#  '18013',
#  '18012',
#  '17981',
#  '18011',
#  '18008',
#  '18010']

# %%
# send a get request for each event_id
# modern events is a list of the html for each of the event pages
modern_events = []
for event_id in event_ids:
    modern_event = requests.get('http://mtgtop8.com/event?e={}'.format(event_id))
    modern_events.append(modern_event)
    print(modern_event.status_code)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
# create a BeautifulSoup object for each of the event ids
# modern_event_soups is a list of BeautifulSoup objects for each of the event pages
modern_event_soups = []
for modern_event in modern_events:
    modern_event_soups.append(BeautifulSoup(modern_event.content, 'html.parser'))

# %%
# Get to the table that contains the links to all the deck lists
# deck_list_tables is a list of the tables containing the deck lists for each event page
deck_list_tables = []

for modern_event_soup in modern_event_soups:
    deck_list_table = modern_event_soup.find_all('table')[3].find_all('a')
    deck_list_tables.append(deck_list_table)


# deck_list_table = modern_event_soups.find_all('table')[3].find_all('a')

deck_list_tables[0]
# Out:
# [<a href="" target="_blank"></a>,
#  <a class="topic" href="?e=18048&amp;d=311953&amp;f=MO">Dsg</a>,
#  <a class="topic" href="search?player=Maxime+Valentin">Maxime Valentin</a>,
#  <a href="?e=18048&amp;d=311954&amp;f=MO">Gw Elves</a>,
#  <a class="player" href="search?player=Marc+Chassagne">Marc Chassagne</a>,
#  <a href="?e=18048&amp;d=311952&amp;f=MO">Creature Toolbox</a>,
#  <a class="player" href="search?player=Lo%EFc+Grenier">Loïc Grenier</a>,
#  <a href="?e=18048&amp;d=311951&amp;f=MO">Jeskai Control</a>,
#  <a class="player" href="search?player=Aur%E9lien+Leroy">Aurélien Leroy</a>,
#  <a href="mtgo?d=311953&amp;f=Modern_Dsg_by_Maxime_Valentin">MTGO</a>,
#  <a href="dec?d=311953&amp;f=Modern_Dsg_by_Maxime_Valentin">.dec</a>,
#  <a href="archetype?a=636">Death's Shadow decks</a>,
#  <a href="tcg_redir?f=MO&amp;c=2 Blood Crypt||4 Bloodstained Mire||2 Ceremonious Rejection||2 Collective Brutality||4 Death's Shadow||1 Disdainful Stroke||2 Dismember||3 Fatal Push||2 Gurmag Angler||2 Inquisition of Kozilek||1 Island||1 Izzet Staticaster||2 Kolaghan's Command||1 Kozilek's Return||2 Liliana of the Veil||1 Liliana, the Last Hope||4 Opt||4 Polluted Delta||1 Pyroclasm||3 Scalding Tarn||1 Serum Visions||4 Snapcaster Mage||1 Steam Vents||4 Street Wraith||4 Stubborn Denial||1 Swamp||2 Tasigur, the Golden Fang||2 Temur Battle Rage||4 Thought Scour||4 Thoughtseize||2 Watery Grave||2 Young Pyromancer||" target="_blank">TCGplayer</a>]

# %%
for item in deck_list_tables[0]:
    print(item)
# Out:
# <a href="" target="_blank"></a>
# <a class="topic" href="?e=18048&amp;d=311953&amp;f=MO">Dsg</a>
# <a class="topic" href="search?player=Maxime+Valentin">Maxime Valentin</a>
# <a href="?e=18048&amp;d=311954&amp;f=MO">Gw Elves</a>
# <a class="player" href="search?player=Marc+Chassagne">Marc Chassagne</a>
# <a href="?e=18048&amp;d=311952&amp;f=MO">Creature Toolbox</a>
# <a class="player" href="search?player=Lo%EFc+Grenier">Loïc Grenier</a>
# <a href="?e=18048&amp;d=311951&amp;f=MO">Jeskai Control</a>
# <a class="player" href="search?player=Aur%E9lien+Leroy">Aurélien Leroy</a>
# <a href="mtgo?d=311953&amp;f=Modern_Dsg_by_Maxime_Valentin">MTGO</a>
# <a href="dec?d=311953&amp;f=Modern_Dsg_by_Maxime_Valentin">.dec</a>
# <a href="archetype?a=636">Death's Shadow decks</a>
# <a href="tcg_redir?f=MO&amp;c=2 Blood Crypt||4 Bloodstained Mire||2 Ceremonious Rejection||2 Collective Brutality||4 Death's Shadow||1 Disdainful Stroke||2 Dismember||3 Fatal Push||2 Gurmag Angler||2 Inquisition of Kozilek||1 Island||1 Izzet Staticaster||2 Kolaghan's Command||1 Kozilek's Return||2 Liliana of the Veil||1 Liliana, the Last Hope||4 Opt||4 Polluted Delta||1 Pyroclasm||3 Scalding Tarn||1 Serum Visions||4 Snapcaster Mage||1 Steam Vents||4 Street Wraith||4 Stubborn Denial||1 Swamp||2 Tasigur, the Golden Fang||2 Temur Battle Rage||4 Thought Scour||4 Thoughtseize||2 Watery Grave||2 Young Pyromancer||" target="_blank">TCGplayer</a>

# %%
# deck_list_ids is a list of all the unique ids for the deck lists
deck_list_ids = [] 

# loop through each table of deck lists for each even tpage
for deck_list_table in deck_list_tables:
    # loop through each of the anchor tags in each of the deck list tables
    for anchor in deck_list_table:
        # find only anchors where 'e=' and 'd=' are in the href. This is only the actual deck lists
        if ('d=' in anchor['href'] and 'e=' in anchor['href']):
            # add the id to the list
            deck_list_ids.append(re.search('d=(\d+)&', anchor['href']).group(1))

# %%
prop_name['strong']

# %%
len(deck_list_ids)
# Out:
# 55

# %%
# mtg_deck_lists is a dictionary with key=deck_list_id and value is a deck list
mtg_deck_lists = {}

# loop through each of the deck ids
for deck_list_id in deck_list_ids:
    # send a get request for each of the deck lists in mtgo format
    mtg_deck_list = requests.get('http://mtgtop8.com/mtgo?d={}'.format(deck_list_id), headers={'User-Agent': 'Getting some deck lists'})
    # add the id and deck lists to the dictionary
    mtg_deck_lists[deck_list_id] =  mtg_deck_list.content.decode().split('\r\n')
    
    # wait 2 seconds between each requests, hoping not to get blocked
    time.sleep(2 + random.random())

# %%
mtg_deck_lists
# Out:
# {'311539': ['4 Bloodghast',
#   '2 Golgari Thug',
#   '1 Haunted Dead',
#   '4 Insolent Neonate',
#   '4 Narcomoeba',
#   '4 Prized Amalgam',
#   '4 Stinkweed Imp',
#   '4 Cathartic Reunion',
#   '3 Conflagrate',
#   '4 Faithless Looting',
#   '3 Life from the Loam',
#   '2 Darkblast',
#   '3 Arid Mesa',
#   '2 Blackcleave Cliffs',
#   '1 Blood Crypt',
#   '2 Bloodstained Mire',
#   '3 Copperline Gorge',
#   '2 Dakmor Salvage',
#   '2 Gemstone Mine',
#   '2 Mountain',
#   '2 Stomping Ground',
#   '2 Wooded Foothills',
#   'Sideboard',
#   '1 Darkblast',
#   '2 Abrupt Decay',
#   '2 Ancient Grudge',
#   '2 Collective Brutality',
#   '4 Leyline of the Void',
#   '2 Lightning Axe',
#   '2 Thoughtseize',
#   ''],
#  '311540': ['2 Karn Liberated',
#   '3 Endbringer',
#   '4 Matter Reshaper',
#   '4 Reality Smasher',
#   '4 Thought-Knot Seer',
#   '4 Walking Ballista',
#   '2 All Is Dust',
#   '2 Dismember',
#   '2 Warping Wail',
#   '4 Chalice of the Void',
#   '4 Expedition Map',
#   '1 Relic of Progenitus',
#   '2 Cavern of Souls',
#   '4 Eldrazi Temple',
#   '3 Ghost Quarter',
#   '1 Sea Gate Wreckage',
#   "4 Urza's Mine",
#   "4 Urza's Power Plant",
#   "4 Urza's Tower",
#   '2 Wastes',
#   'Sideboard',
#   '2 Relic of Progenitus',
#   '1 Basilisk Collar',
#   "2 Grafdigger's Cage",
#   '2 Hangarback Walker',
#   '2 Pithing Needle',
#   '2 Ratchet Bomb',
#   '2 Surgical Extraction',
#   '2 Thorn of Amethyst',
#   ''],
#  '311541': ['4 Saheeli Rai',
#   '1 Avalanche Riders',
#   '4 Birds of Paradise',
#   '1 Eternal Witness',
#   '1 Felidar Guardian',
#   '4 Lotus Cobra',
#   '1 Meddling Mage',
#   '1 Reflector Mage',
#   '4 Renegade Rallier',
#   "1 Sigarda, Heron's Grace",
#   '2 Sun Titan',
#   '1 Thragtusk',
#   '4 Voice of Resurgence',
#   '4 Eldritch Evolution',
#   "1 Summoner's Pact",
#   '4 Oath of Nissa',
#   '1 Breeding Pool',
#   '3 Flooded Strand',
#   '2 Forest',
#   '1 Hallowed Fountain',
#   '2 Horizon Canopy',
#   '4 Misty Rainforest',
#   '2 Plains',
#   '1 Sacred Foundry',
#   '1 Stomping Ground',
#   '1 Temple Garden',
#   '4 Windswept Heath',
#   'Sideboard',
#   '1 Acidic Slime',
#   '1 Eidolon of Rhetoric',
#   '2 Gaddock Teeg',
#   '1 Glen Elendra Archmage',
#   '1 Izzet Staticaster',
#   "1 Kataki, War's Wage",
#   '1 Obstinate Baloth',
#   '1 Path to Exile',
#   '2 Reclamation Sage',
#   '2 Stony Silence',
#   '2 Unified Will',
#   ''],
#  '311542': ['4 Baral, Chief of Compliance',
#   '3 Goblin Electromancer',
#   '1 Empty the Warrens',
#   '2 Grapeshot',
#   '2 Past in Flames',
#   '4 Serum Visions',
#   '4 Sleight of Hand',
#   '4 Desperate Ritual',
#   '4 Gifts Ungiven',
#   '4 Manamorphose',
#   '1 Noxious Revival',
#   '2 Peer Through Depths',
#   '4 Pyretic Ritual',
#   '3 Remand',
#   '3 Island',
#   '1 Mountain',
#   '3 Polluted Delta',
#   '4 Scalding Tarn',
#   '4 Spirebluff Canal',
#   '3 Steam Vents',
#   'Sideboard',
#   '2 Empty the Warrens',
#   '2 Blood Moon',
#   '2 Dismember',
#   '1 Dispel',
#   '1 Echoing Truth',
#   '2 Gigadrowse',
#   '3 Lightning Bolt',
#   '2 Shattering Spree',
#   ''],
#  '311543': ['4 Arcbound Ravager',
#   '2 Etched Champion',
#   '1 Hope of Ghirapur',
#   '2 Master of Etherium',
#   '2 Memnite',
#   '4 Ornithopter',
#   '4 Signal Pest',
#   '4 Steel Overseer',
#   '3 Vault Skirge',
#   '3 Thoughtcast',
#   '2 Galvanic Blast',
#   '4 Darksteel Citadel',
#   '4 Cranial Plating',
#   '4 Mox Opal',
#   '4 Springleaf Drum',
#   '1 Welding Jar',
#   '3 Blinkmoth Nexus',
#   '1 Glimmervoid',
#   '4 Inkmoth Nexus',
#   '1 Snow-Covered Island',
#   '3 Spire of Industry',
#   'Sideboard',
#   '1 Etched Champion',
#   '2 Ancient Grudge',
#   '1 Blood Moon',
#   '1 Dispatch',
#   '2 Ghirapur Aether Grid',
#   "1 Grafdigger's Cage",
#   '1 Rule of Law',
#   '1 Silence',
#   '2 Spell Pierce',
#   '2 Thoughtseize',
#   '1 Wear / Tear',
#   ''],
#  '311744': ['1 Mountain',
#   '1 Plains',
#   '4 Island',
#   '2 Field of Ruin',
#   '1 Sacred Foundry',
#   '2 Hallowed Fountain',
#   '2 Steam Vents',
#   '4 Scalding Tarn',
#   '4 Flooded Strand',
#   '4 Celestial Colonnade',
#   '1 Spell Snare',
#   "1 Sphinx's Revelation",
#   '2 Search for Azcanta',
#   '4 Lightning Bolt',
#   '3 Lightning Helix',
#   '4 Path to Exile',
#   '3 Logic Knot',
#   '4 Cryptic Command',
#   '3 Supreme Verdict',
#   '4 Serum Visions',
#   '2 Vendilion Clique',
#   '4 Snapcaster Mage',
#   'Sideboard',
#   '1 Disdainful Stroke',
#   '2 Dispel',
#   '2 Negate',
#   '3 Ceremonious Rejection',
#   '1 Surgical Extraction',
#   '1 Blessed Alliance',
#   '1 Settle the Wreckage',
#   '1 Secure the Wastes',
#   '2 Runed Halo',
#   '1 Izzet Staticaster',
#   ''],
#  '311745': ['1 Ghost Quarter',
#   '2 Llanowar Wastes',
#   '1 Blooming Marsh',
#   "4 Urza's Tower",
#   "4 Urza's Power Plant",
#   "4 Urza's Mine",
#   '4 Ancient Stirrings',
#   '4 Sylvan Scrying',
#   '4 Oblivion Stone',
#   '4 Expedition Map',
#   '4 Chromatic Star',
#   '4 Chromatic Sphere',
#   '3 Fatal Push',
#   '3 Relic of Progenitus',
#   '4 Karn Liberated',
#   '1 Ugin, the Spirit Dragon',
#   '2 Wurmcoil Engine',
#   '2 World Breaker',
#   '2 Ulamog, the Ceaseless Hunger',
#   '2 Forest',
#   '1 Sanctum of Ugin',
#   'Sideboard',
#   "2 Nature's Claim",
#   '2 Seal of Primordium',
#   '3 Thragtusk',
#   '2 Thoughtseize',
#   '4 Collective Brutality',
#   '2 Ravenous Trap',
#   ''],
#  '311746': ['3 Forest',
#   '7 Mountain',
#   '1 Verdant Catacombs',
#   '2 Windswept Heath',
#   '3 Stomping Ground',
#   '4 Cinder Glade',
#   '4 Wooded Foothills',
#   '4 Valakut, the Molten Pinnacle',
#   '3 Anger of the Gods',
#   '2 Lightning Bolt',
#   '1 Hour of Promise',
#   "2 Summoner's Pact",
#   '1 Chandra, Torch of Defiance',
#   '2 Prismatic Omen',
#   '2 Explore',
#   '4 Sakura-Tribe Elder',
#   '3 Farseek',
#   '4 Search for Tomorrow',
#   '4 Scapeshift',
#   '4 Primeval Titan',
#   'Sideboard',
#   '1 Chameleon Colossus',
#   '1 Guttural Response',
#   '1 Thrun, the Last Troll',
#   '1 Crumble to Dust',
#   '1 Obstinate Baloth',
#   '1 Thragtusk',
#   '1 Courser of Kruphix',
#   '2 Reclamation Sage',
#   '2 Beast Within',
#   '1 Ancient Grudge',
#   '2 Relic of Progenitus',
#   '1 Inferno Titan',
#   ''],
#  '311747': ['4 Expedition Map',
#   '4 Sylvan Scrying',
#   '4 Ancient Stirrings',
#   '2 Fatal Push',
#   '1 Sanctum of Ugin',
#   '1 Ghost Quarter',
#   '2 Forest',
#   '1 Blooming Marsh',
#   '2 Llanowar Wastes',
#   "4 Urza's Power Plant",
#   "4 Urza's Tower",
#   "4 Urza's Mine",
#   '1 Walking Ballista',
#   '3 Wurmcoil Engine',
#   '2 Ugin, the Spirit Dragon',
#   '1 Ulamog, the Ceaseless Hunger',
#   '1 World Breaker',
#   '4 Karn Liberated',
#   '4 Chromatic Star',
#   '4 Chromatic Sphere',
#   '4 Oblivion Stone',
#   '3 Relic of Progenitus',
#   'Sideboard',
#   '1 Warping Wail',
#   "3 Nature's Claim",
#   '2 Thoughtseize',
#   '2 Dismember',
#   '4 Collective Brutality',
#   '3 Thragtusk',
#   ''],
#  '311748': ['4 Thought-Knot Seer',
#   '4 Chalice of the Void',
#   '4 Expedition Map',
#   '2 Dismember',
#   '1 Mind Stone',
#   '2 All Is Dust',
#   '2 Karn Liberated',
#   '1 Ulamog, the Ceaseless Hunger',
#   '1 Wurmcoil Engine',
#   '1 Skysovereign, Consul Flagship',
#   '2 Endbringer',
#   '4 Walking Ballista',
#   '4 Reality Smasher',
#   '2 Wastes',
#   '1 Sea Gate Wreckage',
#   '1 Sanctum of Ugin',
#   '2 Ghost Quarter',
#   '2 Cavern of Souls',
#   '4 Eldrazi Temple',
#   "4 Urza's Power Plant",
#   "8 Urza's Tower",
#   '4 Matter Reshaper',
#   'Sideboard',
#   '2 Warping Wail',
#   '2 Spatial Contortion',
#   '1 Wurmcoil Engine',
#   '1 Sorcerous Spyglass',
#   '2 Relic of Progenitus',
#   '2 Hangarback Walker',
#   '1 Basilisk Collar',
#   "2 Grafdigger's Cage",
#   '2 Ratchet Bomb',
#   ''],
#  '311749': ['2 Blood Moon',
#   "2 Kolaghan's Command",
#   '2 Collective Brutality',
#   '2 Fatal Push',
#   '2 Terminate',
#   '4 Faithless Looting',
#   '4 Lightning Bolt',
#   '4 Lingering Souls',
#   '4 Inquisition of Kozilek',
#   '4 Thoughtseize',
#   '2 Goblin Rabblemaster',
#   '4 Bedlam Reveler',
#   '4 Young Pyromancer',
#   '1 Dreadbore',
#   '1 Swamp',
#   '3 Mountain',
#   '1 Blood Crypt',
#   '2 Sacred Foundry',
#   '2 Marsh Flats',
#   '4 Blackcleave Cliffs',
#   '4 Bloodstained Mire',
#   '2 Wooded Foothills',
#   'Sideboard',
#   '1 Blood Moon',
#   '2 Collective Brutality',
#   '4 Leyline of the Void',
#   '2 Wear / Tear',
#   '2 Crumble to Dust',
#   '1 Shattering Spree',
#   '1 Anger of the Gods',
#   '1 Chandra, Torch of Defiance',
#   '1 Kambal, Consul of Allocation',
#   ''],
#  '311750': ['2 Overgrown Tomb',
#   '1 Blood Crypt',
#   '1 Stomping Ground',
#   '3 Raging Ravine',
#   '1 Blooming Marsh',
#   '1 Forest',
#   '2 Swamp',
#   '4 Blackcleave Cliffs',
#   '4 Verdant Catacombs',
#   '4 Bloodstained Mire',
#   '3 Inquisition of Kozilek',
#   '3 Thoughtseize',
#   '3 Fatal Push',
#   '3 Lightning Bolt',
#   '3 Terminate',
#   '2 Abrupt Decay',
#   '1 Maelstrom Pulse',
#   "2 Kolaghan's Command",
#   '1 Liliana, the Last Hope',
#   '4 Liliana of the Veil',
#   '2 Goblin Rabblemaster',
#   '2 Scavenging Ooze',
#   '4 Dark Confidant',
#   '4 Tarmogoyf',
#   'Sideboard',
#   '1 Golgari Charm',
#   '1 Jund Charm',
#   '1 Anger of the Gods',
#   '2 Huntmaster of the Fells',
#   '2 Nihil Spellbomb',
#   "1 Grafdigger's Cage",
#   '2 Collective Brutality',
#   '2 Crumble to Dust',
#   '1 Damnation',
#   '1 Deglamer',
#   '1 Blightning',
#   ''],
#  '311751': ['3 Mountain',
#   '2 Arid Mesa',
#   '1 Scalding Tarn',
#   '3 Wooded Foothills',
#   '4 Bloodstained Mire',
#   '3 Inspiring Vantage',
#   '2 Sacred Foundry',
#   '1 Stomping Ground',
#   '4 Rift Bolt',
#   '4 Skullcrack',
#   '4 Boros Charm',
#   '4 Lava Spike',
#   '4 Lightning Helix',
#   '4 Lightning Bolt',
#   '4 Searing Blaze',
#   '4 Eidolon of the Great Revel',
#   '4 Monastery Swiftspear',
#   '1 Grim Lavamancer',
#   '4 Goblin Guide',
#   'Sideboard',
#   '2 Exquisite Firecraft',
#   '3 Path to Exile',
#   '3 Searing Blood',
#   '3 Deflecting Palm',
#   '4 Destructive Revelry',
#   ''],
#  '311757': ['4 Temple of Malice',
#   '5 Swamp',
#   '3 Mountain',
#   '4 Bloodstained Mire',
#   '1 Blood Crypt',
#   '2 Blackcleave Cliffs',
#   '4 Through the Breach',
#   '4 Nourishing Shoal',
#   '1 Manamorphose',
#   '1 Lightning Axe',
#   "4 Goryo's Vengeance",
#   '2 Desperate Ritual',
#   "4 Night's Whisper",
#   '4 Faithless Looting',
#   '1 Collective Brutality',
#   '2 Cathartic Reunion',
#   '4 Worldspine Wurm',
#   '4 Simian Spirit Guide',
#   '4 Griselbrand',
#   '2 Borborygmos Enraged',
#   'Sideboard',
#   '2 Shattering Spree',
#   '2 Pact of Negation',
#   '2 Chalice of the Void',
#   "2 Bontu's Last Reckoning",
#   '3 Blood Moon',
#   '2 Anger of the Gods',
#   '1 Lightning Axe',
#   '1 Collective Brutality',
#   ''],
#  '311758': ['1 Steam Vents',
#   '1 Sacred Foundry',
#   '1 Plains',
#   '3 Misty Rainforest',
#   '2 Horizon Canopy',
#   '1 Hallowed Fountain',
#   '1 Ghost Quarter',
#   '1 Forest',
#   '4 Arid Mesa',
#   '4 Path to Exile',
#   '3 Lightning Helix',
#   '4 Lightning Bolt',
#   '1 Bant Charm',
#   '4 Wild Nacatl',
#   '3 Voice of Resurgence',
#   '4 Tarmogoyf',
#   '4 Spell Queller',
#   '1 Qasali Pridemage',
#   '4 Noble Hierarch',
#   '4 Knight of the Reliquary',
#   '2 Elspeth, Knight-Errant',
#   '4 Windswept Heath',
#   '1 Temple Garden',
#   '2 Stomping Ground',
#   'Sideboard',
#   '1 Lightning Helix',
#   '2 Unified Will',
#   '1 Tectonic Edge',
#   '2 Stony Silence',
#   '1 Negate',
#   '2 Mirran Crusader',
#   '1 Izzet Staticaster',
#   '1 Grim Lavamancer',
#   "2 Grafdigger's Cage",
#   '2 Dispel',
#   ''],
#  '311759': ['4 Chromatic Star',
#   '4 Chromatic Sphere',
#   '3 Fatal Push',
#   '4 Sylvan Scrying',
#   '4 Ancient Stirrings',
#   '3 Wurmcoil Engine',
#   '1 World Breaker',
#   '1 Walking Ballista',
#   '1 Ulamog, the Ceaseless Hunger',
#   '2 Ugin, the Spirit Dragon',
#   '4 Karn Liberated',
#   "4 Urza's Tower",
#   "4 Urza's Power Plant",
#   "4 Urza's Mine",
#   '1 Sanctum of Ugin',
#   '3 Llanowar Wastes',
#   '2 Forest',
#   '1 Blooming Marsh',
#   '3 Relic of Progenitus',
#   '3 Oblivion Stone',
#   '4 Expedition Map',
#   'Sideboard',
#   '3 Thragtusk',
#   '2 Thoughtseize',
#   '1 Swamp',
#   '2 Seal of Primordium',
#   "2 Nature's Claim",
#   '1 Ghost Quarter',
#   '4 Collective Brutality',
#   ''],
#  '311760': ['2 Steam Vents',
#   '1 Spirebluff Canal',
#   '4 Scalding Tarn',
#   '1 Sulfur Falls',
#   '4 Snapcaster Mage',
#   '2 Geist of Saint Traft',
#   '1 Sacred Foundry',
#   '1 Plains',
#   '3 Island',
#   '2 Hallowed Fountain',
#   '4 Flooded Strand',
#   '1 Field of Ruin',
#   '4 Celestial Colonnade',
#   '1 Search for Azcanta',
#   '2 Spell Snare',
#   '4 Path to Exile',
#   '4 Opt',
#   '1 Negate',
#   '2 Logic Knot',
#   '2 Lightning Helix',
#   '4 Lightning Bolt',
#   '2 Electrolyze',
#   '3 Cryptic Command',
#   '1 Serum Visions',
#   '2 Vendilion Clique',
#   '2 Spell Queller',
#   'Sideboard',
#   '1 Wear / Tear',
#   '1 Relic of Progenitus',
#   '2 Leyline of Sanctity',
#   '1 Flashfreeze',
#   '1 Engineered Explosives',
#   '1 Dispel',
#   '2 Disdainful Stroke',
#   '3 Ceremonious Rejection',
#   '2 Celestial Purge',
#   '1 Anger of the Gods',
#   ''],
#  '311761': ['2 Sulfur Falls',
#   '2 Steam Vents',
#   '4 Scalding Tarn',
#   '1 Sacred Foundry',
#   '1 Plains',
#   '1 Mountain',
#   '3 Island',
#   '2 Hallowed Fountain',
#   '2 Spell Snare',
#   '4 Celestial Colonnade',
#   '4 Flooded Strand',
#   '4 Path to Exile',
#   '1 Mana Leak',
#   '2 Logic Knot',
#   '3 Lightning Helix',
#   '4 Lightning Bolt',
#   '2 Electrolyze',
#   '2 Cryptic Command',
#   '4 Serum Visions',
#   '1 Vendilion Clique',
#   '4 Spell Queller',
#   '4 Snapcaster Mage',
#   '3 Geist of Saint Traft',
#   'Sideboard',
#   '1 Supreme Verdict',
#   '1 Stony Silence',
#   '2 Relic of Progenitus',
#   '2 Pia and Kiran Nalaar',
#   '1 Negate',
#   '1 Izzet Staticaster',
#   '1 Engineered Explosives',
#   '1 Dispel',
#   '2 Disdainful Stroke',
#   '1 Crumble to Dust',
#   '1 Celestial Purge',
#   '1 Abrade',
#   ''],
#  '311774': ["4 Urza's Tower",
#   "4 Urza's Power Plant",
#   "4 Urza's Mine",
#   '1 Tolaria West',
#   '1 Tectonic Edge',
#   '2 Snow-Covered Island',
#   '1 River of Tears',
#   '1 Oboro, Palace in the Clouds',
#   '4 Island',
#   '1 Gemstone Caverns',
#   '1 Academy Ruins',
#   '1 Talisman of Dominance',
#   '1 Oblivion Stone',
#   '2 Mindslaver',
#   '4 Expedition Map',
#   '1 Engineered Explosives',
#   '1 Chalice of the Void',
#   '4 Thirst for Knowledge',
#   '1 Supreme Will',
#   '3 Repeal',
#   '3 Remand',
#   '1 Gifts Ungiven',
#   '1 Cyclonic Rift',
#   '4 Condescend',
#   '1 Wurmcoil Engine',
#   '1 Walking Ballista',
#   '1 Trinket Mage',
#   '1 Treasure Mage',
#   '1 Sundering Titan',
#   '1 Snapcaster Mage',
#   '1 Platinum Angel',
#   '1 Emrakul, the Promised End',
#   '1 Ugin, the Spirit Dragon',
#   'Sideboard',
#   '2 Surgical Extraction',
#   '2 Spreading Seas',
#   '2 Spatial Contortion',
#   "1 Hurkyl's Recall",
#   "1 Grafdigger's Cage",
#   '1 Field of Ruin',
#   '2 Dismember',
#   '1 Crucible of Worlds',
#   '1 Engineered Explosives',
#   '1 Chalice of the Void',
#   '1 Wurmcoil Engine',
#   ''],
#  '311775': ['4 Thalia, Guardian of Thraben',
#   '3 Reflector Mage',
#   '4 Phantasmal Image',
#   '4 Noble Hierarch',
#   '4 Meddling Mage',
#   '4 Mantis Rider',
#   '4 Kitesail Freebooter',
#   '1 Kessig Malcontents',
#   '4 Champion of the Parish',
#   '4 Unclaimed Territory',
#   '1 Seachrome Coast',
#   '1 Plains',
#   '1 Mana Confluence',
#   '4 Horizon Canopy',
#   '4 Cavern of Souls',
#   '4 Ancient Ziggurat',
#   '4 Aether Vial',
#   '1 Xathrid Necromancer',
#   "4 Thalia's Lieutenant",
#   'Sideboard',
#   '2 Vithian Renegades',
#   '3 Sin Collector',
#   '1 Reflector Mage',
#   '1 Kessig Malcontents',
#   '1 Rest in Peace',
#   '1 Orzhov Pontiff',
#   '1 Izzet Staticaster',
#   "1 Grafdigger's Cage",
#   '2 Dismember',
#   '1 Dark Confidant',
#   '1 Anafenza, the Foremost',
#   ''],
#  '311776': ['3 Wooded Foothills',
#   '1 Swamp',
#   '2 Sacred Foundry',
#   '3 Mountain',
#   '1 Marsh Flats',
#   '4 Bloodstained Mire',
#   '1 Blood Crypt',
#   '4 Blackcleave Cliffs',
#   '1 Blood Moon',
#   '2 Terminate',
#   '2 Lightning Helix',
#   '4 Lightning Bolt',
#   "3 Kolaghan's Command",
#   '3 Thoughtseize',
#   '4 Lingering Souls',
#   '4 Inquisition of Kozilek',
#   '1 Forked Bolt',
#   '4 Faithless Looting',
#   '1 Dreadbore',
#   '2 Collective Brutality',
#   '4 Young Pyromancer',
#   '2 Monastery Swiftspear',
#   '4 Bedlam Reveler',
#   'Sideboard',
#   '2 Wear / Tear',
#   '1 Shattering Spree',
#   '2 Pithing Needle',
#   '4 Leyline of the Void',
#   '1 Kambal, Consul of Allocation',
#   '2 Fatal Push',
#   "1 Dragon's Claw",
#   '2 Blood Moon',
#   ''],
#  '311777': ['2 Tarfire',
#   '2 Wooded Foothills',
#   '4 Verdant Catacombs',
#   '1 Swamp',
#   '1 Stomping Ground',
#   '2 Polluted Delta',
#   '1 Overgrown Tomb',
#   '1 Godless Shrine',
#   '1 Forest',
#   '4 Bloodstained Mire',
#   '1 Blood Crypt',
#   "4 Mishra's Bauble",
#   '1 Terminate',
#   '3 Temur Battle Rage',
#   "2 Kolaghan's Command",
#   '2 Fatal Push',
#   '4 Traverse the Ulvenwald',
#   '4 Thoughtseize',
#   '4 Inquisition of Kozilek',
#   '4 Tarmogoyf',
#   '4 Street Wraith',
#   '2 Grim Flayer',
#   "4 Death's Shadow",
#   '2 Liliana of the Veil',
#   'Sideboard',
#   '2 Surgical Extraction',
#   '1 Ranger of Eos',
#   '1 Nihil Spellbomb',
#   '3 Lingering Souls',
#   '2 Fulminator Mage',
#   '1 Eidolon of Rhetoric',
#   '2 Collective Brutality',
#   '2 Ancient Grudge',
#   '1 Fatal Push',
#   ''],
#  '311778': ['4 Unclaimed Territory',
#   '2 Seachrome Coast',
#   '1 Plains',
#   '4 Horizon Canopy',
#   '4 Cavern of Souls',
#   '4 Ancient Ziggurat',
#   '4 Aether Vial',
#   "4 Thalia's Lieutenant",
#   '1 Thalia, Heretic Cathar',
#   '4 Thalia, Guardian of Thraben',
#   '4 Reflector Mage',
#   '4 Phantasmal Image',
#   '4 Noble Hierarch',
#   '4 Meddling Mage',
#   '4 Mantis Rider',
#   '4 Kitesail Freebooter',
#   '4 Champion of the Parish',
#   'Sideboard',
#   '1 Xathrid Necromancer',
#   '2 Vithian Renegades',
#   '3 Sin Collector',
#   '1 Riders of Gavony',
#   '2 Izzet Staticaster',
#   '1 Hostage Taker',
#   "2 Grafdigger's Cage",
#   '2 Dismember',
#   '1 Anafenza, the Foremost',
#   ''],
#  '311779': ['4 Wooded Foothills',
#   '4 Windswept Heath',
#   '3 Stomping Ground',
#   '1 Mountain',
#   '9 Forest',
#   '4 Utopia Sprawl',
#   '4 Blood Moon',
#   '4 Stone Rain',
#   '1 Primal Command',
#   '3 Mwonvuli Acid-Moss',
#   '4 Tireless Tracker',
#   '2 Stormbreath Dragon',
#   '2 Pia and Kiran Nalaar',
#   '2 Obstinate Baloth',
#   '2 Inferno Titan',
#   '1 Courser of Kruphix',
#   '2 Chameleon Colossus',
#   '2 Birds of Paradise',
#   '4 Arbor Elf',
#   '2 Chandra, Torch of Defiance',
#   'Sideboard',
#   '3 Trinisphere',
#   '2 Relic of Progenitus',
#   '2 Kitchen Finks',
#   '2 Fracturing Gust',
#   '3 Anger of the Gods',
#   '1 Ancient Grudge',
#   '2 Abrade',
#   ''],
#  '311780': ['1 Watery Grave',
#   '4 Verdant Catacombs',
#   '1 Swamp',
#   '4 Polluted Delta',
#   '1 Overgrown Tomb',
#   '4 Marsh Flats',
#   '1 Godless Shrine',
#   '1 Forest',
#   '1 Breeding Pool',
#   "4 Mishra's Bauble",
#   '3 Stubborn Denial',
#   '4 Fatal Push',
#   '2 Dismember',
#   '2 Abrupt Decay',
#   '4 Traverse the Ulvenwald',
#   '4 Thoughtseize',
#   '3 Inquisition of Kozilek',
#   '4 Tarmogoyf',
#   '4 Street Wraith',
#   '2 Snapcaster Mage',
#   "4 Death's Shadow",
#   '2 Architects of Will',
#   'Sideboard',
#   '2 Surgical Extraction',
#   '2 Stony Silence',
#   '1 Ranger of Eos',
#   '1 Nihil Spellbomb',
#   '1 Maelstrom Pulse',
#   '3 Lingering Souls',
#   '1 Flaying Tendrils',
#   '2 Disdainful Stroke',
#   '1 Collective Brutality',
#   '1 Stubborn Denial',
#   ''],
#  '311781': ['4 Wooded Foothills',
#   '1 Stomping Ground',
#   '2 Sacred Foundry',
#   '2 Mountain',
#   '2 Inspiring Vantage',
#   '4 Bloodstained Mire',
#   '4 Arid Mesa',
#   '4 Skullcrack',
#   '3 Searing Blaze',
#   '4 Lightning Helix',
#   '4 Lightning Bolt',
#   '4 Boros Charm',
#   '4 Rift Bolt',
#   '4 Lava Spike',
#   '4 Monastery Swiftspear',
#   '2 Grim Lavamancer',
#   '4 Goblin Guide',
#   '4 Eidolon of the Great Revel',
#   'Sideboard',
#   '4 Molten Rain',
#   "2 Grafdigger's Cage",
#   '4 Destructive Revelry',
#   '1 Deflecting Palm',
#   '3 Chained to the Rocks',
#   '1 Searing Blaze',
#   ''],
#  '311782': ['4 Arcbound Ravager',
#   '2 Etched Champion',
#   '2 Glint-Nest Crane',
#   '2 Master of Etherium',
#   '2 Memnite',
#   '4 Ornithopter',
#   '4 Signal Pest',
#   '4 Steel Overseer',
#   '4 Vault Skirge',
#   '1 Thoughtcast',
#   '2 Galvanic Blast',
#   '4 Darksteel Citadel',
#   '4 Cranial Plating',
#   '4 Mox Opal',
#   '4 Springleaf Drum',
#   '4 Blinkmoth Nexus',
#   '1 Glimmervoid',
#   '4 Inkmoth Nexus',
#   '1 Island',
#   '3 Spire of Industry',
#   'Sideboard',
#   '2 Etched Champion',
#   '2 Ancient Grudge',
#   '1 Blood Moon',
#   '1 Dispatch',
#   '2 Ghirapur Aether Grid',
#   "1 Grafdigger's Cage",
#   '2 Rest in Peace',
#   '1 Stubborn Denial',
#   '2 Thoughtseize',
#   '1 Whipflare',
#   ''],
#  '311783': ['2 Platinum Emperion',
#   '4 Snapcaster Mage',
#   '2 Vendilion Clique',
#   '4 Madcap Experiment',
#   '4 Serum Visions',
#   '2 Cryptic Command',
#   '2 Electrolyze',
#   '2 Izzet Charm',
#   '4 Lightning Bolt',
#   '4 Opt',
#   '4 Remand',
#   '2 Spell Snare',
#   '2 Blood Moon',
#   '2 Desolate Lighthouse',
#   '1 Flooded Strand',
#   '6 Island',
#   '1 Misty Rainforest',
#   '1 Mountain',
#   '2 Polluted Delta',
#   '4 Scalding Tarn',
#   '2 Steam Vents',
#   '3 Sulfur Falls',
#   'Sideboard',
#   '1 Izzet Staticaster',
#   '4 Logic Knot',
#   '2 Surgical Extraction',
#   '4 Young Pyromancer',
#   '2 Anger of the Gods',
#   '2 Dispel',
#   ''],
#  '311784': ['4 Eidolon of the Great Revel',
#   '4 Goblin Guide',
#   '4 Monastery Swiftspear',
#   '4 Lava Spike',
#   '4 Rift Bolt',
#   '4 Boros Charm',
#   '4 Lightning Bolt',
#   '4 Lightning Helix',
#   '1 Mutagenic Growth',
#   '4 Searing Blaze',
#   '4 Skullcrack',
#   '4 Arid Mesa',
#   '4 Bloodstained Mire',
#   '3 Inspiring Vantage',
#   '2 Mountain',
#   '2 Sacred Foundry',
#   '1 Stomping Ground',
#   '3 Wooded Foothills',
#   'Sideboard',
#   '2 Deflecting Palm',
#   '4 Destructive Revelry',
#   '3 Kor Firewalker',
#   '2 Path to Exile',
#   '2 Rest in Peace',
#   '2 Searing Blood',
#   ''],
#  '311785': ['4 Flooded Strand',
#   '1 Island',
#   '4 Polluted Delta',
#   '1 Steam Vents',
#   '1 Swamp',
#   '2 Watery Grave',
#   "4 Death's Shadow",
#   '2 Gurmag Angler',
#   '4 Snapcaster Mage',
#   '4 Street Wraith',
#   '2 Tasigur, the Golden Fang',
#   '2 Inquisition of Kozilek',
#   '4 Thoughtseize',
#   '1 Dismember',
#   '4 Fatal Push',
#   "1 Kolaghan's Command",
#   '4 Opt',
#   '3 Stubborn Denial',
#   '2 Temur Battle Rage',
#   '1 Terminate',
#   '4 Thought Scour',
#   '1 Blood Crypt',
#   '4 Bloodstained Mire',
#   'Sideboard',
#   '2 Anger of the Gods',
#   '1 By Force',
#   '2 Ceremonious Rejection',
#   '2 Collective Brutality',
#   '1 Echoing Truth',
#   '1 Izzet Staticaster',
#   '1 Liliana, the Last Hope',
#   '2 Nihil Spellbomb',
#   '2 Young Pyromancer',
#   '1 Stubborn Denial',
#   ''],
#  '311786': ['4 Birds of Paradise',
#   '4 Devoted Druid',
#   '4 Duskwatch Recruiter',
#   '3 Eternal Witness',
#   '4 Kitchen Finks',
#   '2 Noble Hierarch',
#   '1 Qasali Pridemage',
#   '1 Scavenging Ooze',
#   '1 Tireless Tracker',
#   '1 Viscera Seer',
#   '4 Vizier of Remedies',
#   '1 Walking Ballista',
#   '4 Chord of Calling',
#   '4 Collected Company',
#   '2 Forest',
#   '2 Gavony Township',
#   '1 Godless Shrine',
#   '2 Horizon Canopy',
#   '1 Overgrown Tomb',
#   '1 Plains',
#   '2 Razorverge Thicket',
#   '1 Swamp',
#   '2 Temple Garden',
#   '4 Verdant Catacombs',
#   '4 Windswept Heath',
#   'Sideboard',
#   '3 Tidehollow Sculler',
#   '1 Reclamation Sage',
#   '2 Path to Exile',
#   '1 Scavenging Ooze',
#   '2 Abrupt Decay',
#   '1 Burrenton Forge-Tender',
#   '1 Eidolon of Rhetoric',
#   '1 Ethersworn Canonist',
#   "1 Kataki, War's Wage",
#   '1 Loaming Shaman',
#   '1 Orzhov Pontiff',
#   ''],
#  '311787': ['3 Spire of Industry',
#   '4 Arcbound Ravager',
#   '3 Etched Champion',
#   '2 Master of Etherium',
#   '2 Memnite',
#   '4 Ornithopter',
#   '4 Signal Pest',
#   '4 Steel Overseer',
#   '4 Vault Skirge',
#   '3 Galvanic Blast',
#   '4 Darksteel Citadel',
#   '4 Cranial Plating',
#   '4 Mox Opal',
#   '4 Springleaf Drum',
#   '1 Welding Jar',
#   '4 Blinkmoth Nexus',
#   '1 Glimmervoid',
#   '4 Inkmoth Nexus',
#   '1 Mountain',
#   'Sideboard',
#   '2 Rest in Peace',
#   '2 Ghirapur Aether Grid',
#   '2 Blood Moon',
#   '2 Ancient Grudge',
#   '1 Etched Champion',
#   '2 Whipflare',
#   '2 Thoughtseize',
#   "1 Shapers' Sanctuary",
#   '1 Rule of Law',
#   ''],
#  '311788': ["2 Smuggler's Copter",
#   '4 Aether Vial',
#   '4 Path to Exile',
#   '4 Thraben Inspector',
#   '4 Thought-Knot Seer',
#   '4 Thalia, Guardian of Thraben',
#   '4 Leonin Arbiter',
#   '4 Flickerwisp',
#   '3 Eldrazi Displacer',
#   '4 Blade Splicer',
#   '2 Tectonic Edge',
#   '2 Shefet Dunes',
#   '8 Plains',
#   '3 Horizon Canopy',
#   '4 Ghost Quarter',
#   '4 Eldrazi Temple',
#   'Sideboard',
#   '4 Relic of Progenitus',
#   '2 Spatial Contortion',
#   '3 Stony Silence',
#   '1 Weathered Wayfarer',
#   '1 Phyrexian Revoker',
#   '2 Mirran Crusader',
#   '2 Burrenton Forge-Tender',
#   ''],
#  '311789': ['1 Gemstone Caverns',
#   '1 Academy Ruins',
#   '1 Talisman of Dominance',
#   '1 Relic of Progenitus',
#   '1 Oblivion Stone',
#   '2 Mindslaver',
#   '1 Ugin, the Spirit Dragon',
#   '1 Platinum Angel',
#   '1 Snapcaster Mage',
#   '1 Sundering Titan',
#   '1 Treasure Mage',
#   '1 Trinket Mage',
#   '1 Walking Ballista',
#   '1 Wurmcoil Engine',
#   '4 Condescend',
#   '1 Cyclonic Rift',
#   '1 Dismember',
#   '3 Remand',
#   '3 Repeal',
#   '1 Supreme Will',
#   '4 Thirst for Knowledge',
#   '1 Chalice of the Void',
#   '1 Engineered Explosives',
#   '4 Expedition Map',
#   "4 Urza's Tower",
#   "4 Urza's Power Plant",
#   "4 Urza's Mine",
#   '1 Tolaria West',
#   '1 Tectonic Edge',
#   '1 River of Tears',
#   '1 Oboro, Palace in the Clouds',
#   '6 Island',
#   'Sideboard',
#   '1 Wurmcoil Engine',
#   '2 Dismember',
#   '1 Chalice of the Void',
#   '1 Surgical Extraction',
#   '1 Spreading Seas',
#   '1 Spell Snare',
#   '3 Spatial Contortion',
#   "1 Hurkyl's Recall",
#   "1 Grafdigger's Cage",
#   '1 Field of Ruin',
#   '1 Dispel',
#   '1 Crucible of Worlds',
#   ''],
#  '311790': ['3 Wooded Foothills',
#   '1 Scalding Tarn',
#   '2 Sacred Foundry',
#   '3 Mountain',
#   '4 Inspiring Vantage',
#   '3 Bloodstained Mire',
#   '4 Arid Mesa',
#   '4 Eidolon of the Great Revel',
#   '4 Goblin Guide',
#   '2 Grim Lavamancer',
#   '4 Monastery Swiftspear',
#   '4 Lava Spike',
#   '4 Rift Bolt',
#   '4 Boros Charm',
#   '4 Lightning Bolt',
#   '4 Lightning Helix',
#   '4 Searing Blaze',
#   '2 Skullcrack',
#   'Sideboard',
#   '1 Path to Exile',
#   '2 Relic of Progenitus',
#   '2 Searing Blood',
#   '1 Shattering Spree',
#   '2 Smash to Smithereens',
#   '1 Deflecting Palm',
#   '3 Chained to the Rocks',
#   '1 Grim Lavamancer',
#   '2 Skullcrack',
#   ''],
#  '311791': ["4 Urza's Power Plant",
#   "4 Urza's Mine",
#   '1 Sanctum of Ugin',
#   '1 Ghost Quarter',
#   '5 Forest',
#   '2 Oblivion Stone',
#   '4 Expedition Map',
#   '4 Chromatic Star',
#   '4 Chromatic Sphere',
#   '2 Dismember',
#   '4 Sylvan Scrying',
#   '4 Ancient Stirrings',
#   '2 All Is Dust',
#   '3 Wurmcoil Engine',
#   '1 World Breaker',
#   '2 Walking Ballista',
#   '2 Ulamog, the Ceaseless Hunger',
#   '4 Karn Liberated',
#   '2 Ugin, the Spirit Dragon',
#   '1 Emrakul, the Promised End',
#   "4 Urza's Tower",
#   'Sideboard',
#   '1 Crucible of Worlds',
#   "3 Nature's Claim",
#   '1 Pithing Needle',
#   '2 Relic of Progenitus',
#   '2 Spatial Contortion',
#   '3 Thought-Knot Seer',
#   '3 Thragtusk',
#   ''],
#  '311858': ['3 Island',
#   '3 Remand',
#   '4 Pyretic Ritual',
#   '3 Opt',
#   '1 Noxious Revival',
#   '4 Manamorphose',
#   '4 Gifts Ungiven',
#   '4 Desperate Ritual',
#   '4 Sleight of Hand',
#   '4 Serum Visions',
#   '2 Past in Flames',
#   '3 Grapeshot',
#   '3 Goblin Electromancer',
#   '4 Baral, Chief of Compliance',
#   '4 Steam Vents',
#   '4 Spirebluff Canal',
#   '1 Snow-Covered Island',
#   '4 Shivan Reef',
#   '1 Mountain',
#   'Sideboard',
#   '1 Wipe Away',
#   '2 Shattering Spree',
#   '4 Pieces of the Puzzle',
#   '3 Lightning Bolt',
#   '1 Gigadrowse',
#   '2 Empty the Warrens',
#   '1 Dispel',
#   '1 Dismember',
#   ''],
#  '311859': ['4 Eldrazi Displacer',
#   '4 Drowner of Hope',
#   '3 Yavimaya Coast',
#   '2 Windswept Heath',
#   '1 Temple Garden',
#   '1 Plains',
#   '2 Misty Rainforest',
#   '1 Island',
#   '1 Hallowed Fountain',
#   '1 Forest',
#   '4 Eldrazi Temple',
#   '4 Cavern of Souls',
#   '3 Brushland',
#   '1 Breeding Pool',
#   '4 Engineered Explosives',
#   '4 Ancient Stirrings',
#   '4 Thought-Knot Seer',
#   '4 Reality Smasher',
#   '4 Noble Hierarch',
#   '4 Matter Reshaper',
#   '4 Eldrazi Skyspawner',
#   'Sideboard',
#   '4 Stubborn Denial',
#   '1 Rest in Peace',
#   '4 Relic of Progenitus',
#   '4 Reflector Mage',
#   "1 Grafdigger's Cage",
#   '1 Chalice of the Void',
#   ''],
#  '311860': ['1 Swamp',
#   '3 Shambling Vent',
#   '2 Plains',
#   '4 Ghost Quarter',
#   '4 Eldrazi Temple',
#   '4 Concealed Courtyard',
#   '4 Caves of Koilos',
#   '4 Aether Vial',
#   '4 Path to Exile',
#   '4 Tidehollow Sculler',
#   '4 Thought-Knot Seer',
#   '3 Thalia, Guardian of Thraben',
#   '4 Leonin Arbiter',
#   '4 Flickerwisp',
#   '4 Eldrazi Displacer',
#   '3 Dark Confidant',
#   '1 Blade Splicer',
#   '3 Wasteland Strangler',
#   'Sideboard',
#   '3 Stony Silence',
#   '2 Rest in Peace',
#   '1 Orzhov Pontiff',
#   '3 Mirran Crusader',
#   '2 Kambal, Consul of Allocation',
#   '1 Gonti, Lord of Luxury',
#   '1 Blessed Alliance',
#   '1 Aven Mindcensor',
#   '1 Wasteland Strangler',
#   ''],
#  '311861': ['4 Verdant Catacombs',
#   '1 Twilight Mire',
#   '4 Swamp',
#   '2 Forest',
#   '4 Hissing Quagmire',
#   '1 Overgrown Tomb',
#   '4 Field of Ruin',
#   '4 Blooming Marsh',
#   '4 Fatal Push',
#   '1 Dismember',
#   '2 Abrupt Decay',
#   '4 Thoughtseize',
#   '2 Maelstrom Pulse',
#   '4 Inquisition of Kozilek',
#   '2 Tireless Tracker',
#   '4 Tarmogoyf',
#   '4 Scavenging Ooze',
#   '4 Dark Confidant',
#   '1 Liliana, the Last Hope',
#   '4 Liliana of the Veil',
#   'Sideboard',
#   '2 Surgical Extraction',
#   '2 Nihil Spellbomb',
#   '4 Fulminator Mage',
#   '1 Flaying Tendrils',
#   '1 Duress',
#   '1 Damnation',
#   '1 Creeping Corrosion',
#   '2 Collective Brutality',
#   '1 Liliana, the Last Hope',
#   ''],
#  '311862': ['2 Temple of Enlightenment',
#   '4 Temple of Deceit',
#   '4 Seachrome Coast',
#   '2 Plains',
#   '4 Gemstone Mine',
#   '4 Darkslick Shores',
#   '4 Phyrexian Unlife',
#   '4 Pentad Prism',
#   '4 Lotus Bloom',
#   '3 Spoils of the Vault',
#   '3 Pact of Negation',
#   '1 Manamorphose',
#   '1 Lightning Storm',
#   "4 Angel's Grace",
#   '4 Ad Nauseam',
#   '3 Sleight of Hand',
#   '4 Serum Visions',
#   '4 Simian Spirit Guide',
#   '1 Laboratory Maniac',
#   'Sideboard',
#   '1 Slaughter Pact',
#   "1 Patrician's Scorn",
#   '4 Leyline of Sanctity',
#   "1 Hurkyl's Recall",
#   '1 Holy Day',
#   '3 Grave Titan',
#   "1 Elspeth, Sun's Champion",
#   '1 Dragonlord Dromoka',
#   '1 Disenchant',
#   '1 Pact of Negation',
#   ''],
#  '311895': ['4 Spire of Industry',
#   '1 Island',
#   '4 Inkmoth Nexus',
#   '4 Blinkmoth Nexus',
#   '1 Welding Jar',
#   '4 Springleaf Drum',
#   '4 Mox Opal',
#   '4 Cranial Plating',
#   '4 Darksteel Citadel',
#   '3 Galvanic Blast',
#   '4 Steel Overseer',
#   '4 Signal Pest',
#   '4 Ornithopter',
#   '4 Memnite',
#   '3 Master of Etherium',
#   '1 Glint-Nest Crane',
#   '4 Arcbound Ravager',
#   '3 Etched Champion',
#   'Sideboard',
#   '2 Ghirapur Aether Grid',
#   "2 Grafdigger's Cage",
#   '4 Thoughtseize',
#   '1 Wear / Tear',
#   '3 Blood Moon',
#   '2 Ancient Grudge',
#   '1 Etched Champion',
#   ''],
#  '311896': ['4 Ancient Ziggurat',
#   '4 Aether Vial',
#   "4 Thalia's Lieutenant",
#   '4 Thalia, Guardian of Thraben',
#   '4 Reflector Mage',
#   '4 Phantasmal Image',
#   '4 Noble Hierarch',
#   '4 Meddling Mage',
#   '4 Mantis Rider',
#   '4 Kitesail Freebooter',
#   '1 Dark Confidant',
#   '4 Champion of the Parish',
#   '4 Cavern of Souls',
#   '4 Horizon Canopy',
#   '1 Plains',
#   '2 Seachrome Coast',
#   '4 Unclaimed Territory',
#   'Sideboard',
#   '2 Dark Confidant',
#   '1 Anafenza, the Foremost',
#   '2 Dismember',
#   "2 Grafdigger's Cage",
#   '2 Izzet Staticaster',
#   '1 Mirran Crusader',
#   '2 Sin Collector',
#   '2 Vithian Renegades',
#   '1 Xathrid Necromancer',
#   ''],
#  '311897': ['3 Wooded Foothills',
#   '1 Swamp',
#   '2 Sacred Foundry',
#   '3 Mountain',
#   '1 Marsh Flats',
#   '4 Bloodstained Mire',
#   '1 Blood Crypt',
#   '2 Terminate',
#   '1 Blood Moon',
#   '4 Blackcleave Cliffs',
#   '2 Lightning Helix',
#   '4 Lightning Bolt',
#   "3 Kolaghan's Command",
#   '1 Burst Lightning',
#   '3 Thoughtseize',
#   '4 Lingering Souls',
#   '4 Inquisition of Kozilek',
#   '2 Forked Bolt',
#   '4 Faithless Looting',
#   '1 Dreadbore',
#   '4 Young Pyromancer',
#   '2 Monastery Swiftspear',
#   '4 Bedlam Reveler',
#   'Sideboard',
#   '2 Wear / Tear',
#   '1 Shattering Spree',
#   '2 Pithing Needle',
#   '4 Leyline of the Void',
#   '1 Kambal, Consul of Allocation',
#   '2 Fatal Push',
#   "1 Dragon's Claw",
#   '2 Blood Moon',
#   ''],
#  '311898': ['4 Unclaimed Territory',
#   '1 Seachrome Coast',
#   '1 Plains',
#   '1 Mana Confluence',
#   '4 Horizon Canopy',
#   '4 Cavern of Souls',
#   '4 Ancient Ziggurat',
#   "4 Thalia's Lieutenant",
#   '2 Thalia, Heretic Cathar',
#   '4 Thalia, Guardian of Thraben',
#   '3 Reflector Mage',
#   '4 Noble Hierarch',
#   '4 Meddling Mage',
#   '4 Mayor of Avabruck',
#   '4 Mantis Rider',
#   '4 Kitesail Freebooter',
#   '4 Champion of the Parish',
#   "4 Avacyn's Pilgrim",
#   'Sideboard',
#   '2 Sin Collector',
#   '3 Izzet Staticaster',
#   '2 Gaddock Teeg',
#   '1 Fiend Hunter',
#   '2 Dismember',
#   '2 Dark Confidant',
#   '1 Reflector Mage',
#   '2 Stony Silence',
#   ''],
#  '311899': ['1 Windswept Heath',
#   '4 Verdant Catacombs',
#   '1 Temple Garden',
#   '4 Tectonic Edge',
#   '2 Swamp',
#   '2 Overgrown Tomb',
#   '3 Marsh Flats',
#   '2 Hissing Quagmire',
#   '1 Godless Shrine',
#   '1 Forest',
#   '3 Blooming Marsh',
#   '1 Go for the Throat',
#   '3 Fatal Push',
#   '2 Dismember',
#   '2 Abrupt Decay',
#   '3 Thoughtseize',
#   '2 Maelstrom Pulse',
#   '4 Lingering Souls',
#   '3 Inquisition of Kozilek',
#   '4 Tarmogoyf',
#   '3 Scavenging Ooze',
#   '2 Kalitas, Traitor of Ghet',
#   '3 Grim Flayer',
#   '4 Liliana of the Veil',
#   'Sideboard',
#   '2 Surgical Extraction',
#   '2 Stony Silence',
#   '2 Nihil Spellbomb',
#   '1 Liliana, the Last Hope',
#   '3 Fulminator Mage',
#   '1 Flaying Tendrils',
#   '2 Damnation',
#   '2 Collective Brutality',
#   ''],
#  '311900': ['4 Primeval Titan',
#   '4 Sakura-Tribe Elder',
#   '1 Thragtusk',
#   '1 Wood Elves',
#   '2 Explore',
#   '3 Farseek',
#   '4 Scapeshift',
#   '4 Search for Tomorrow',
#   '2 Sweltering Suns',
#   '4 Lightning Bolt',
#   "2 Summoner's Pact",
#   '2 Relic of Progenitus',
#   '3 Cinder Glade',
#   '2 Forest',
#   '7 Mountain',
#   '1 Sheltered Thicket',
#   '3 Stomping Ground',
#   '4 Valakut, the Molten Pinnacle',
#   '3 Windswept Heath',
#   '4 Wooded Foothills',
#   'Sideboard',
#   '2 Witchbane Orb',
#   '1 Ancient Grudge',
#   '1 Anger of the Gods',
#   '1 Beast Within',
#   '1 Chameleon Colossus',
#   '1 Engineered Explosives',
#   "1 Grafdigger's Cage",
#   "2 Nature's Claim",
#   '2 Obstinate Baloth',
#   '1 Reclamation Sage',
#   '2 Tireless Tracker',
#   ''],
#  '311901': ['4 Unclaimed Territory',
#   '4 Seachrome Coast',
#   '1 Plains',
#   '3 Horizon Canopy',
#   '3 Cavern of Souls',
#   '4 Ancient Ziggurat',
#   '4 Aether Vial',
#   '1 Xathrid Necromancer',
#   "4 Thalia's Lieutenant",
#   '4 Thalia, Guardian of Thraben',
#   '4 Reflector Mage',
#   '4 Phantasmal Image',
#   '4 Noble Hierarch',
#   '4 Meddling Mage',
#   '4 Mantis Rider',
#   '4 Kitesail Freebooter',
#   '4 Champion of the Parish',
#   'Sideboard',
#   '2 Vithian Renegades',
#   '1 Stony Silence',
#   '3 Sin Collector',
#   '2 Izzet Staticaster',
#   '3 Hostage Taker',
#   "2 Grafdigger's Cage",
#   '2 Dismember',
#   ''],
#  '311902': ['2 Blackcleave Cliffs',
#   '4 Pentad Prism',
#   '4 Through the Breach',
#   '4 Izzet Charm',
#   "4 Goryo's Vengeance",
#   '3 Thoughtseize',
#   '2 Serum Visions',
#   '2 Pieces of the Puzzle',
#   '4 Faithless Looting',
#   '2 Collective Brutality',
#   '4 Simian Spirit Guide',
#   '4 Griselbrand',
#   '4 Emrakul, the Aeons Torn',
#   '1 Watery Grave',
#   '1 Swamp',
#   '1 Steam Vents',
#   '4 Polluted Delta',
#   '1 Island',
#   '2 Gemstone Mine',
#   '1 Darkslick Shores',
#   '3 Creeping Tar Pit',
#   '1 Breeding Pool',
#   '2 Blood Crypt',
#   'Sideboard',
#   '2 Pyroclasm',
#   '3 Pact of Negation',
#   '1 Nihil Spellbomb',
#   '4 Leyline of Sanctity',
#   '1 Boseiju, Who Shelters All',
#   '2 Blood Moon',
#   '2 Ancient Grudge',
#   ''],
#  '311903': ['3 Architects of Will',
#   '4 Curator of Mysteries',
#   '1 Nimble Obstructionist',
#   '3 Street Wraith',
#   '4 Striped Riverwinder',
#   '4 Ancestral Vision',
#   '4 Living End',
#   '4 Cryptic Command',
#   '4 Remand',
#   '2 Spell Pierce',
#   '4 As Foretold',
#   '1 Search for Azcanta',
#   '1 Bojuka Bog',
#   '1 Darkslick Shores',
#   '2 Field of Ruin',
#   '1 Ghost Quarter',
#   '10 Island',
#   '2 River of Tears',
#   '1 Sunken Ruins',
#   '4 Tolaria West',
#   'Sideboard',
#   '1 Nimble Obstructionist',
#   '1 Ceremonious Rejection',
#   '2 Collective Brutality',
#   '2 Dismember',
#   '1 Dispel',
#   '1 Engineered Explosives',
#   "2 Hurkyl's Recall",
#   '1 Leyline of Sanctity',
#   '4 Leyline of the Void',
#   ''],
#  '311904': ['4 Urborg, Tomb of Yawgmoth',
#   '16 Swamp',
#   '4 Mutavault',
#   '4 Shrieking Affliction',
#   '4 The Rack',
#   '2 Funeral Charm',
#   '3 Fatal Push',
#   '1 Dismember',
#   '3 Wrench Mind',
#   '3 Thoughtseize',
#   '4 Smallpox',
#   "4 Raven's Crime",
#   '4 Inquisition of Kozilek',
#   '4 Liliana of the Veil',
#   'Sideboard',
#   '3 Delirium Skeins',
#   '4 Leyline of the Void',
#   '2 Shadow of Doubt',
#   "2 Death's Shadow",
#   "2 Bontu's Last Reckoning",
#   '1 Asylum Visitor',
#   '1 Fatal Push',
#   ''],
#  '311951': ['3 Island',
#   '2 Electrolyze',
#   '4 Serum Visions',
#   '2 Plains',
#   '2 Logic Knot',
#   '1 Mountain',
#   '4 Snapcaster Mage',
#   '4 Scalding Tarn',
#   '3 Lightning Helix',
#   '4 Flooded Strand',
#   '2 Geist of Saint Traft',
#   '1 Mana Leak',
#   '4 Spell Queller',
#   '4 Lightning Bolt',
#   '2 Hallowed Fountain',
#   '1 Sacred Foundry',
#   '3 Cryptic Command',
#   '4 Celestial Colonnade',
#   '2 Spell Snare',
#   '1 Vendilion Clique',
#   '1 Sulfur Falls',
#   '2 Steam Vents',
#   '4 Path to Exile',
#   'Sideboard',
#   '1 Celestial Purge',
#   '1 Supreme Verdict',
#   '1 Wear / Tear',
#   '1 Crumble to Dust',
#   '2 Stony Silence',
#   '2 Relic of Progenitus',
#   '2 Ceremonious Rejection',
#   '1 Izzet Staticaster',
#   '2 Runed Halo',
#   '1 Engineered Explosives',
#   '1 Dispel',
#   ''],
#  '311952': ['1 Godless Shrine',
#   '2 Duskwatch Recruiter',
#   '1 Renegade Rallier',
#   '1 Plains',
#   '1 Blooming Marsh',
#   '1 Swamp',
#   '1 Scavenging Ooze',
#   '4 Windswept Heath',
#   '2 Temple Garden',
#   '3 Razorverge Thicket',
#   '4 Kitchen Finks',
#   '1 Rhonas the Indomitable',
#   '1 Overgrown Tomb',
#   '3 Eternal Witness',
#   '4 Vizier of Remedies',
#   '1 Viscera Seer',
#   '1 Walking Ballista',
#   '4 Birds of Paradise',
#   '3 Noble Hierarch',
#   '1 Qasali Pridemage',
#   '3 Verdant Catacombs',
#   '1 Woodland Cemetery',
#   '4 Collected Company',
#   '2 Gavony Township',
#   '4 Chord of Calling',
#   '4 Devoted Druid',
#   '2 Forest',
#   'Sideboard',
#   '1 Eidolon of Rhetoric',
#   '2 Abrupt Decay',
#   '2 Sin Collector',
#   '2 Path to Exile',
#   '2 Voice of Resurgence',
#   '1 Reclamation Sage',
#   '1 Orzhov Pontiff',
#   '2 Tidehollow Sculler',
#   "2 Kataki, War's Wage",
#   ''],
#  '311953': ['2 Watery Grave',
#   '1 Serum Visions',
#   '4 Thought Scour',
#   '1 Island',
#   '4 Street Wraith',
#   '4 Snapcaster Mage',
#   '1 Swamp',
#   "4 Death's Shadow",
#   '4 Opt',
#   '3 Fatal Push',
#   '1 Temur Battle Rage',
#   '4 Thoughtseize',
#   '2 Tasigur, the Golden Fang',
#   '2 Gurmag Angler',
#   '1 Steam Vents',
#   "2 Kolaghan's Command",
#   '2 Blood Crypt',
#   '2 Dismember',
#   '3 Stubborn Denial',
#   '4 Polluted Delta',
#   '4 Bloodstained Mire',
#   '2 Inquisition of Kozilek',
#   '3 Scalding Tarn',
#   'Sideboard',
#   '1 Izzet Staticaster',
#   '2 Young Pyromancer',
#   '2 Liliana of the Veil',
#   '1 Liliana, the Last Hope',
#   '1 Temur Battle Rage',
#   '1 Pyroclasm',
#   '2 Ceremonious Rejection',
#   "1 Kozilek's Return",
#   '1 Disdainful Stroke',
#   '2 Collective Brutality',
#   '1 Stubborn Denial',
#   ''],
#  '311954': ['1 Craterhoof Behemoth',
#   '4 Horizon Canopy',
#   '3 Cavern of Souls',
#   '4 Collected Company',
#   '1 Wooded Foothills',
#   '4 Chord of Calling',
#   '4 Llanowar Elves',
#   '4 Devoted Druid',
#   '4 Heritage Druid',
#   '4 Ezuri, Renegade Leader',
#   '3 Forest',
#   '4 Razorverge Thicket',
#   '1 Temple Garden',
#   '4 Elvish Mystic',
#   '1 Pendelhaven',
#   '3 Nettle Sentinel',
#   '1 Eternal Witness',
#   '1 Elvish Visionary',
#   '1 Vizier of Remedies',
#   "4 Dwynen's Elite",
#   '4 Elvish Archdruid',
#   'Sideboard',
#   "1 Kataki, War's Wage",
#   '2 Scavenging Ooze',
#   '1 Fracturing Gust',
#   '2 Rest in Peace',
#   '1 Reclamation Sage',
#   "1 Shapers' Sanctuary",
#   '2 Stony Silence',
#   '1 Burrenton Forge-Tender',
#   '1 Aegis of the Gods',
#   '1 Selfless Spirit',
#   '1 Eidolon of Rhetoric',
#   '1 Aven Mindcensor',
#   '']}

# %% [markdown]
# # Functionalizing the scraping process

# %%
def get_event_ids(front_page):
    """Takes in the front page of mtgtop8.com and returns a list of all the event ids
    
    INPUT:
        - front_page: BeautifulSoup object of the event page
        
    OUTPUT:
        - event_ids: List of all the event ids from the 'Last 10 Events' table"""

    event_list = [event['href'] for event in front_page.find_all('table')[2]
                  .find('td').find_next_sibling().find_all('table')[1].find_all('a')]

    # use map() and regular expressions to get the event id out of the anchor tags
    event_ids = list(map(lambda x: re.search("e=(\d+)&", x).group(1), event_list))

    return event_ids

# %%
response = requests.get('http://mtgtop8.com/format?f=MO&meta=44')
print(response.status_code)

front_page = BeautifulSoup(response.content, 'html.parser')
# Out:
# 200

# %%
get_event_ids(front_page)
# Out:
# ['18048',
#  '18038',
#  '18037',
#  '18029',
#  '18013',
#  '18012',
#  '17981',
#  '18011',
#  '18008',
#  '18010']

# %%
def get_deck_ids(event_page):
    """Takes in an event page and returns a list of all the deck ids on that page.
    
    INPUT:
        - event_page: BeautifulSoup objet of the event page from mtgtop8.com
        
    OUTPUT:
        - deck_ids: List of all deck ids on the page"""
    
    # Get to the table that contains the links to all the deck lists
    deck_list_table = event_page.find_all('table')[3].find_all('a')


    # deck_list_ids is a list of all the unique ids for the deck lists
    deck_ids = [] 

    # loop through each of the anchor tags in each of the deck list tables
    for anchor in deck_list_table:
        # find only anchors where 'e=' and 'd=' are in the href. This is only the actual deck lists
        if ('d=' in anchor['href'] and 'e=' in anchor['href']):
            # add the id to the list
            deck_ids.append(re.search('d=(\d+)&', anchor['href']).group(1)) 
                
    return deck_ids

# %%
response = requests.get('http://mtgtop8.com/event?e=18048&f=MO')
print(response.status_code)

event_page = BeautifulSoup(response.content, 'html.parser')
# Out:
# 200

# %%
get_deck_ids(event_page)
# Out:
# ['311953', '311954', '311952', '311951']

# %%
def deck_request(deck_id):
    """Takes a deck_id and returns the response from the request. Errors will come later.
    
    INPUT:
        - deck_id: the unique id for the desired deck list from mtgtop8.com
        
    OUTPUT:
        - response: the response from the get request"""
    
    response = requests.get('http://mtgtop8.com/mtgo?d={}'.format(deck_id), 
                            headers={'User-Agent': 'Getting some deck lists'})
    
    # FUTURE WORK: check the status code
    return response

# %%
deck_request(311953).text.split('\r\n')
# Out:
# ['2 Watery Grave',
#  '1 Serum Visions',
#  '4 Thought Scour',
#  '1 Island',
#  '4 Street Wraith',
#  '4 Snapcaster Mage',
#  '1 Swamp',
#  "4 Death's Shadow",
#  '4 Opt',
#  '3 Fatal Push',
#  '1 Temur Battle Rage',
#  '4 Thoughtseize',
#  '2 Tasigur, the Golden Fang',
#  '2 Gurmag Angler',
#  '1 Steam Vents',
#  "2 Kolaghan's Command",
#  '2 Blood Crypt',
#  '2 Dismember',
#  '3 Stubborn Denial',
#  '4 Polluted Delta',
#  '4 Bloodstained Mire',
#  '2 Inquisition of Kozilek',
#  '3 Scalding Tarn',
#  'Sideboard',
#  '1 Izzet Staticaster',
#  '2 Young Pyromancer',
#  '2 Liliana of the Veil',
#  '1 Liliana, the Last Hope',
#  '1 Temur Battle Rage',
#  '1 Pyroclasm',
#  '2 Ceremonious Rejection',
#  "1 Kozilek's Return",
#  '1 Disdainful Stroke',
#  '2 Collective Brutality',
#  '1 Stubborn Denial',
#  '']

# %%
def event_request(event_id):
    """Takes an event_id and returns the response from the request. Errors will come later.
    
    INPUT:
        - event_id: the unique id for the desired event from mtgtop8.com
        
    OUTPUT:
        - response: the response from the get request"""
    
    response = requests.get('http://mtgtop8.com/event?e={}'.format(event_id), 
                            headers={'User-Agent': 'Getting some event info'})
    
    # FUTURE WORK: check the status code
    return response

# %%
get_deck_ids(BeautifulSoup(event_request(18048).text, 'html.parser'))
# Out:
# ['311953', '311954', '311952', '311951']

# %%
def modern_front_page_request(page_number=0):
    """Sends a get request to mtgtop8.com with the given page number
    
    INPUT: 
        - page_number: argument for the get request. page_number of 3 gets decks from 21-30.
                       Default value of 0 to get decks from 1-10.
    
    OUTPUT:
        - response: the response from the get request"""
    
    response = requests.get('http://mtgtop8.com/format?f=MO&meta=44&cp={}'.format(page_number),
                            headers={'User-Agent': 'Modern front page request'})
    
    # FUTURE WORK: check the status code
    return response

# %%
front_page = BeautifulSoup(modern_front_page_request().text, 'html.parser')

# %%
get_event_ids(front_page)
# Out:
# ['18048',
#  '18038',
#  '18037',
#  '18029',
#  '18013',
#  '18012',
#  '17981',
#  '18011',
#  '18008',
#  '18010']

# %%
def event_requests(event_ids):
    """Takes a list of event ids and returns a list of responses from the requests. Errors will come later.
    
    INPUT:
        - event_ids: the list of unique ids for the desired events from mtgtop8.com
        
    OUTPUT:
        - responses: the list of responses from the get requests"""
    
    responses = []
    for event_ids in event_ids:
        response = event_request(event_id)
        responses.append(response)
    
    # FUTURE WORK: check the status code
    return responses

# %%
event_ids = get_event_ids(front_page)

event_ids
# Out:
# ['18048',
#  '18038',
#  '18037',
#  '18029',
#  '18013',
#  '18012',
#  '17981',
#  '18011',
#  '18008',
#  '18010']

# %%
event_requests(event_ids)
# Out:
# [<Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>]

# %%
def deck_requests(deck_ids):
    """Takes a list of deck ids and returns the responses from the requests. Errors will come later.
    
    INPUT:
        - deck_ids: the unique ids for each ofthe desired deck lists from mtgtop8.com
        
    OUTPUT:
        - responses: the responses from the get requests"""
    
    responses = []
    for deck_id in deck_ids:
        response = deck_request(deck_id)
        responses.append(response)
    
    # FUTURE WORK: check the status code
    return responses

# %%
deck_ids = get_deck_ids(BeautifulSoup(event_request(18048).text, 'html.parser'))

deck_ids
# Out:
# ['311953', '311954', '311952', '311951']

# %%
deck_requests(deck_ids)
# Out:
# [<Response [200]>, <Response [200]>, <Response [200]>, <Response [200]>]

# %% [markdown]
# # Getting all Modern Legal Cards

# %%
# used to read all the modern cards from 
import json

# %%
modern_legal_cards = requests.get('https://api.deckbrew.com/mtg/cards?format=modern&page=112')

modern_legal_cards.status_code
# Out:
# 200

# %%
modern_json = json.loads(modern_legal_cards.text)

modern_json
# Out:
# [{'cmc': 1,
#   'colors': ['green'],
#   'cost': '{G}',
#   'editions': [{'artist': 'Tomasz Jedruszek',
#     'flavor': 'On Mirrodin, every conflict ends in either death or darksteel.',
#     'html_url': 'https://deckbrew.com/mtg/cards/209035',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/209035.jpg',
#     'layout': 'normal',
#     'multiverse_id': 209035,
#     'number': '134',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'common',
#     'set': 'Scars of Mirrodin',
#     'set_id': 'SOM',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/SOM',
#     'store_url': 'http://store.tcgplayer.com/magic/scars-of-mirrodin/withstand-death?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=209035',
#     'watermark': 'Mirran'}],
#   'formats': {'commander': 'legal',
#    'legacy': 'legal',
#    'modern': 'legal',
#    'vintage': 'legal'},
#   'id': 'withstand-death',
#   'name': 'Withstand Death',
#   'store_url': 'http://store.tcgplayer.com/magic/scars-of-mirrodin/withstand-death?partner=DECKBREW',
#   'text': 'Target creature gains indestructible until end of turn. (Damage and effects that say "destroy" don\'t destroy it. If its toughness is 0 or less, it\'s still put into its owner\'s graveyard.)',
#   'types': ['instant'],
#   'url': 'https://api.deckbrew.com/mtg/cards/withstand-death'},
#  {'cmc': 6,
#   'cost': '{6}',
#   'editions': [{'artist': 'Izzy',
#     'flavor': 'It strode through the clash of dragons, the fall of Ugin, and the rise of the khans.',
#     'html_url': 'https://deckbrew.com/mtg/cards/386728',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/386728.jpg',
#     'layout': 'normal',
#     'multiverse_id': 386728,
#     'number': '228',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'uncommon',
#     'set': 'Khans of Tarkir',
#     'set_id': 'KTK',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/KTK',
#     'store_url': 'http://store.tcgplayer.com/magic/khans-of-tarkir/witness-of-the-ages?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=386728'}],
#   'formats': {'commander': 'legal',
#    'legacy': 'legal',
#    'modern': 'legal',
#    'vintage': 'legal'},
#   'id': 'witness-of-the-ages',
#   'name': 'Witness of the Ages',
#   'power': '4',
#   'store_url': 'http://store.tcgplayer.com/magic/khans-of-tarkir/witness-of-the-ages?partner=DECKBREW',
#   'subtypes': ['golem'],
#   'text': 'Morph {5} (You may cast this card face down as a 2/2 creature for {3}. Turn it face up any time for its morph cost.)',
#   'toughness': '4',
#   'types': ['artifact', 'creature'],
#   'url': 'https://api.deckbrew.com/mtg/cards/witness-of-the-ages'},
#  {'cmc': 4,
#   'cost': '{3}{B}',
#   'editions': [{'artist': 'Igor Kieryluk',
#     'flavor': '"Ulamog stood before us at Sea Gate, ready to succumb . . . and then Kozilek arose. Whatever hope I had for our world died."\n—Vandri, Kalastria emissary',
#     'html_url': 'https://deckbrew.com/mtg/cards/407592',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/407592.jpg',
#     'layout': 'normal',
#     'multiverse_id': 407592,
#     'number': '82',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'common',
#     'set': 'Oath of the Gatewatch',
#     'set_id': 'OGW',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/OGW',
#     'store_url': 'http://store.tcgplayer.com/magic/oath-of-the-gatewatch/witness-the-end?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=407592'}],
#   'formats': {'commander': 'legal',
#    'legacy': 'legal',
#    'modern': 'legal',
#    'vintage': 'legal'},
#   'id': 'witness-the-end',
#   'name': 'Witness the End',
#   'store_url': 'http://store.tcgplayer.com/magic/oath-of-the-gatewatch/witness-the-end?partner=DECKBREW',
#   'text': 'Devoid (This card has no color.)\nTarget opponent exiles two cards from his or her hand and loses 2 life.',
#   'types': ['sorcery'],
#   'url': 'https://api.deckbrew.com/mtg/cards/witness-the-end'},
#  {'cmc': 7,
#   'colors': ['black'],
#   'cost': '{5}{B}{B}',
#   'editions': [{'artist': 'Kev Walker',
#     'flavor': '"Some images are so powerful that one glance burns them into your mind forever. Come, let us gaze on nothingness."\n—Szadek',
#     'html_url': 'https://deckbrew.com/mtg/cards/107562',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/107562.jpg',
#     'layout': 'normal',
#     'multiverse_id': 107562,
#     'number': '58',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'rare',
#     'set': 'Dissension',
#     'set_id': 'DIS',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/DIS',
#     'store_url': 'http://store.tcgplayer.com/magic/dissension/wits-end?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=107562'},
#    {'artist': 'Chris Rahn',
#     'flavor': '"Your pathetic ideas lie in shambles, Planeswalker. Where is your arrogant pride now?"\n—Nicol Bolas',
#     'html_url': 'https://deckbrew.com/mtg/cards/278076',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/278076.jpg',
#     'layout': 'normal',
#     'multiverse_id': 278076,
#     'number': '117',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'rare',
#     'set': 'Magic 2013',
#     'set_id': 'M13',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/M13',
#     'store_url': 'http://store.tcgplayer.com/magic/magic-2013-(m13)/wits-end?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=278076'}],
#   'formats': {'commander': 'legal',
#    'legacy': 'legal',
#    'modern': 'legal',
#    'vintage': 'legal'},
#   'id': 'wits-end',
#   'name': "Wit's End",
#   'store_url': 'http://store.tcgplayer.com/magic/product/show?partner=DECKBREW&ProductName=wits-end',
#   'text': 'Target player discards his or her hand.',
#   'types': ['sorcery'],
#   'url': 'https://api.deckbrew.com/mtg/cards/wits-end'},
#  {'cmc': 3,
#   'cost': '{3}',
#   'editions': [{'artist': 'Carl Critchlow',
#     'flavor': 'It responds with unnatural precision.',
#     'html_url': 'https://deckbrew.com/mtg/cards/46033',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/46033.jpg',
#     'layout': 'normal',
#     'multiverse_id': 46033,
#     'number': '275',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'common',
#     'set': 'Mirrodin',
#     'set_id': 'MRD',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/MRD',
#     'store_url': 'http://store.tcgplayer.com/magic/mirrodin/wizard-replica?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=46033'},
#    {'artist': 'Carl Critchlow',
#     'flavor': 'It responds with unnatural precision.',
#     'html_url': 'https://deckbrew.com/mtg/cards/205314',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/205314.jpg',
#     'layout': 'normal',
#     'multiverse_id': 205314,
#     'number': '129',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'common',
#     'set': 'Planechase',
#     'set_id': 'HOP',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/HOP',
#     'store_url': 'http://store.tcgplayer.com/magic/planechase/wizard-replica?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=205314'}],
#   'formats': {'commander': 'legal',
#    'legacy': 'legal',
#    'modern': 'legal',
#    'vintage': 'legal'},
#   'id': 'wizard-replica',
#   'name': 'Wizard Replica',
#   'power': '1',
#   'store_url': 'http://store.tcgplayer.com/magic/product/show?partner=DECKBREW&ProductName=wizard-replica',
#   'subtypes': ['wizard'],
#   'text': 'Flying\n{U}, Sacrifice Wizard Replica: Counter target spell unless its controller pays {2}.',
#   'toughness': '3',
#   'types': ['artifact', 'creature'],
#   'url': 'https://api.deckbrew.com/mtg/cards/wizard-replica'},
#  {'cmc': 2,
#   'colors': ['white'],
#   'cost': '{W}{W}',
#   'editions': [{'artist': 'Kev Walker',
#     'flavor': '"Thoughtweft binds us together as one, part of an intricate pattern that would unravel if even one thread came loose."',
#     'html_url': 'https://deckbrew.com/mtg/cards/139716',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/139716.jpg',
#     'layout': 'normal',
#     'multiverse_id': 139716,
#     'number': '49',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'uncommon',
#     'set': 'Lorwyn',
#     'set_id': 'LRW',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/LRW',
#     'store_url': 'http://store.tcgplayer.com/magic/lorwyn/wizened-cenn?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=139716'}],
#   'formats': {'commander': 'legal',
#    'legacy': 'legal',
#    'modern': 'legal',
#    'vintage': 'legal'},
#   'id': 'wizened-cenn',
#   'name': 'Wizened Cenn',
#   'power': '2',
#   'store_url': 'http://store.tcgplayer.com/magic/lorwyn/wizened-cenn?partner=DECKBREW',
#   'subtypes': ['cleric', 'kithkin'],
#   'text': 'Other Kithkin creatures you control get +1/+1.',
#   'toughness': '2',
#   'types': ['creature'],
#   'url': 'https://api.deckbrew.com/mtg/cards/wizened-cenn'},
#  {'cmc': 4,
#   'colors': ['blue'],
#   'cost': '{3}{U}',
#   'editions': [{'artist': 'Greg Staples',
#     'flavor': '"Be careful what information you ask them to find, for it will likely be the subject of tale time at the alehouse."\n—Sirislav, Dimir spy',
#     'html_url': 'https://deckbrew.com/mtg/cards/88971',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/88971.jpg',
#     'layout': 'normal',
#     'multiverse_id': 88971,
#     'number': '75',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'uncommon',
#     'set': 'Ravnica: City of Guilds',
#     'set_id': 'RAV',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/RAV',
#     'store_url': 'http://store.tcgplayer.com/magic/ravnica/wizened-snitches?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=88971'}],
#   'formats': {'commander': 'legal',
#    'legacy': 'legal',
#    'modern': 'legal',
#    'vintage': 'legal'},
#   'id': 'wizened-snitches',
#   'name': 'Wizened Snitches',
#   'power': '1',
#   'store_url': 'http://store.tcgplayer.com/magic/ravnica/wizened-snitches?partner=DECKBREW',
#   'subtypes': ['faerie', 'rogue'],
#   'text': 'Flying\nPlayers play with the top card of their libraries revealed.',
#   'toughness': '3',
#   'types': ['creature'],
#   'url': 'https://api.deckbrew.com/mtg/cards/wizened-snitches'},
#  {'cmc': 5,
#   'colors': ['black'],
#   'cost': '{4}{B}',
#   'editions': [{'artist': 'Matt Thompson',
#     'html_url': 'https://deckbrew.com/mtg/cards/46074',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/46074.jpg',
#     'layout': 'normal',
#     'multiverse_id': 46074,
#     'number': '83',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'uncommon',
#     'set': 'Mirrodin',
#     'set_id': 'MRD',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/MRD',
#     'store_url': 'http://store.tcgplayer.com/magic/mirrodin/woebearer?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=46074'}],
#   'formats': {'commander': 'legal',
#    'legacy': 'legal',
#    'modern': 'legal',
#    'vintage': 'legal'},
#   'id': 'woebearer',
#   'name': 'Woebearer',
#   'power': '2',
#   'store_url': 'http://store.tcgplayer.com/magic/mirrodin/woebearer?partner=DECKBREW',
#   'subtypes': ['zombie'],
#   'text': "Fear (This creature can't be blocked except by artifact creatures and/or black creatures.)\nWhenever Woebearer deals combat damage to a player, you may return target creature card from your graveyard to your hand.",
#   'toughness': '3',
#   'types': ['creature'],
#   'url': 'https://api.deckbrew.com/mtg/cards/woebearer'},
#  {'cmc': 5,
#   'colors': ['black'],
#   'cost': '{3}{B}{B}',
#   'editions': [{'artist': 'Daren Bader',
#     'flavor': 'Each soul he devours adds its hunger to his own.',
#     'html_url': 'https://deckbrew.com/mtg/cards/89049',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/89049.jpg',
#     'layout': 'normal',
#     'multiverse_id': 89049,
#     'number': '113',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'rare',
#     'set': 'Ravnica: City of Guilds',
#     'set_id': 'RAV',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/RAV',
#     'store_url': 'http://store.tcgplayer.com/magic/ravnica/woebringer-demon?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=89049'}],
#   'formats': {'commander': 'legal',
#    'legacy': 'legal',
#    'modern': 'legal',
#    'vintage': 'legal'},
#   'id': 'woebringer-demon',
#   'name': 'Woebringer Demon',
#   'power': '4',
#   'store_url': 'http://store.tcgplayer.com/magic/ravnica/woebringer-demon?partner=DECKBREW',
#   'subtypes': ['demon'],
#   'text': "Flying\nAt the beginning of each player's upkeep, that player sacrifices a creature. If the player can't, sacrifice Woebringer Demon.",
#   'toughness': '4',
#   'types': ['creature'],
#   'url': 'https://api.deckbrew.com/mtg/cards/woebringer-demon'},
#  {'cmc': 6,
#   'colors': ['white'],
#   'cost': '{5}{W}',
#   'editions': [{'artist': 'Izzy',
#     'flavor': 'One head senses the curse. The second loosens it from the soul. The third drinks it as an invigorating mist.',
#     'html_url': 'https://deckbrew.com/mtg/cards/153985',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/153985.jpg',
#     'layout': 'normal',
#     'multiverse_id': 153985,
#     'number': '27',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'common',
#     'set': 'Shadowmoor',
#     'set_id': 'SHM',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/SHM',
#     'store_url': 'http://store.tcgplayer.com/magic/shadowmoor/woeleecher?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=153985'}],
#   'formats': {'commander': 'legal',
#    'legacy': 'legal',
#    'modern': 'legal',
#    'vintage': 'legal'},
#   'id': 'woeleecher',
#   'name': 'Woeleecher',
#   'power': '3',
#   'store_url': 'http://store.tcgplayer.com/magic/shadowmoor/woeleecher?partner=DECKBREW',
#   'subtypes': ['elemental'],
#   'text': '{W}, {T}: Remove a -1/-1 counter from target creature. If you do, you gain 2 life.',
#   'toughness': '5',
#   'types': ['creature'],
#   'url': 'https://api.deckbrew.com/mtg/cards/woeleecher'},
#  {'cmc': 4,
#   'colors': ['white'],
#   'cost': '{2}{W}{W}',
#   'editions': [{'artist': 'Keith Garletts',
#     'flavor': '"A few arrows aren\'t enough to pierce your faith, soldier. You\'ll be back on the battlefield by sun\'s dawn."',
#     'html_url': 'https://deckbrew.com/mtg/cards/88993',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/88993.jpg',
#     'layout': 'normal',
#     'multiverse_id': 88993,
#     'number': '36',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'uncommon',
#     'set': 'Ravnica: City of Guilds',
#     'set_id': 'RAV',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/RAV',
#     'store_url': 'http://store.tcgplayer.com/magic/ravnica/wojek-apothecary?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=88993',
#     'watermark': 'Boros'}],
#   'formats': {'commander': 'legal',
#    'legacy': 'legal',
#    'modern': 'legal',
#    'vintage': 'legal'},
#   'id': 'wojek-apothecary',
#   'name': 'Wojek Apothecary',
#   'power': '1',
#   'store_url': 'http://store.tcgplayer.com/magic/ravnica/wojek-apothecary?partner=DECKBREW',
#   'subtypes': ['cleric', 'human'],
#   'text': 'Radiance — {T}: Prevent the next 1 damage that would be dealt to target creature and each other creature that shares a color with it this turn.',
#   'toughness': '1',
#   'types': ['creature'],
#   'url': 'https://api.deckbrew.com/mtg/cards/wojek-apothecary'},
#  {'cmc': 4,
#   'colors': ['red'],
#   'cost': '{3}{R}',
#   'editions': [{'artist': 'Luca Zontini',
#     'flavor': '"Your brother\'s crimes are your crimes. You stood by and lent support, so you too must face judgment."',
#     'html_url': 'https://deckbrew.com/mtg/cards/88946',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/88946.jpg',
#     'layout': 'normal',
#     'multiverse_id': 88946,
#     'number': '152',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'uncommon',
#     'set': 'Ravnica: City of Guilds',
#     'set_id': 'RAV',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/RAV',
#     'store_url': 'http://store.tcgplayer.com/magic/ravnica/wojek-embermage?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=88946',
#     'watermark': 'Boros'}],
#   'formats': {'commander': 'legal',
#    'legacy': 'legal',
#    'modern': 'legal',
#    'vintage': 'legal'},
#   'id': 'wojek-embermage',
#   'name': 'Wojek Embermage',
#   'power': '1',
#   'store_url': 'http://store.tcgplayer.com/magic/ravnica/wojek-embermage?partner=DECKBREW',
#   'subtypes': ['human', 'wizard'],
#   'text': 'Radiance — {T}: Wojek Embermage deals 1 damage to target creature and each other creature that shares a color with it.',
#   'toughness': '2',
#   'types': ['creature'],
#   'url': 'https://api.deckbrew.com/mtg/cards/wojek-embermage'},
#  {'cmc': 2,
#   'colors': ['red', 'white'],
#   'cost': '{R}{W}',
#   'editions': [{'artist': 'Nic Klein',
#     'flavor': 'Tired of Boros interference, the Rakdos unleashed hellraiser goblins, hoping their corpses would weigh down the halberds.',
#     'html_url': 'https://deckbrew.com/mtg/cards/366265',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/366265.jpg',
#     'layout': 'normal',
#     'multiverse_id': 366265,
#     'number': '208',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'common',
#     'set': 'Gatecrash',
#     'set_id': 'GTC',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/GTC',
#     'store_url': 'http://store.tcgplayer.com/magic/gatecrash/wojek-halberdiers?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=366265',
#     'watermark': 'Boros'}],
#   'formats': {'commander': 'legal',
#    'legacy': 'legal',
#    'modern': 'legal',
#    'vintage': 'legal'},
#   'id': 'wojek-halberdiers',
#   'name': 'Wojek Halberdiers',
#   'power': '3',
#   'store_url': 'http://store.tcgplayer.com/magic/gatecrash/wojek-halberdiers?partner=DECKBREW',
#   'subtypes': ['human', 'soldier'],
#   'text': 'Battalion — Whenever Wojek Halberdiers and at least two other creatures attack, Wojek Halberdiers gains first strike until end of turn.',
#   'toughness': '2',
#   'types': ['creature'],
#   'url': 'https://api.deckbrew.com/mtg/cards/wojek-halberdiers'},
#  {'cmc': 1,
#   'colors': ['white'],
#   'cost': '{W}',
#   'editions': [{'artist': 'Zoltan Boros & Gabor Szikszai',
#     'flavor': 'It is the call to arms, the call to fury, the call to blood.',
#     'html_url': 'https://deckbrew.com/mtg/cards/87896',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/87896.jpg',
#     'layout': 'normal',
#     'multiverse_id': 87896,
#     'number': '37',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'common',
#     'set': 'Ravnica: City of Guilds',
#     'set_id': 'RAV',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/RAV',
#     'store_url': 'http://store.tcgplayer.com/magic/ravnica/wojek-siren?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=87896',
#     'watermark': 'Boros'}],
#   'formats': {'commander': 'legal',
#    'legacy': 'legal',
#    'modern': 'legal',
#    'vintage': 'legal'},
#   'id': 'wojek-siren',
#   'name': 'Wojek Siren',
#   'store_url': 'http://store.tcgplayer.com/magic/ravnica/wojek-siren?partner=DECKBREW',
#   'text': 'Radiance — Target creature and each other creature that shares a color with it get +1/+1 until end of turn.',
#   'types': ['instant'],
#   'url': 'https://api.deckbrew.com/mtg/cards/wojek-siren'},
#  {'cmc': 1,
#   'colors': ['green'],
#   'cost': '{G}',
#   'editions': [{'artist': 'Zoltan Boros',
#     'html_url': 'https://deckbrew.com/mtg/cards/253426',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/253426.jpg',
#     'layout': 'double-faced',
#     'multiverse_id': 253426,
#     'number': '133a',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'rare',
#     'set': 'Dark Ascension',
#     'set_id': 'DKA',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/DKA',
#     'store_url': 'http://store.tcgplayer.com/magic/dark-ascension/wolfbitten-captive?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=253426'}],
#   'formats': {'commander': 'legal',
#    'legacy': 'legal',
#    'modern': 'legal',
#    'vintage': 'legal'},
#   'id': 'wolfbitten-captive',
#   'name': 'Wolfbitten Captive',
#   'power': '1',
#   'store_url': 'http://store.tcgplayer.com/magic/dark-ascension/wolfbitten-captive?partner=DECKBREW',
#   'subtypes': ['human', 'werewolf'],
#   'text': '{1}{G}: Wolfbitten Captive gets +2/+2 until end of turn. Activate this ability only once each turn.\nAt the beginning of each upkeep, if no spells were cast last turn, transform Wolfbitten Captive.',
#   'toughness': '1',
#   'types': ['creature'],
#   'url': 'https://api.deckbrew.com/mtg/cards/wolfbitten-captive'},
#  {'cmc': 4,
#   'colors': ['green'],
#   'cost': '{2}{G}{G}',
#   'editions': [{'artist': 'Chippy',
#     'html_url': 'https://deckbrew.com/mtg/cards/389750',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/389750.jpg',
#     'layout': 'normal',
#     'multiverse_id': 389750,
#     'number': '225',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'rare',
#     'set': 'Commander 2014',
#     'set_id': 'C14',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/C14',
#     'store_url': 'http://store.tcgplayer.com/magic/commander-2014/wolfbriar-elemental?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=389750'},
#    {'artist': 'Chippy',
#     'html_url': 'https://deckbrew.com/mtg/cards/397878',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/397878.jpg',
#     'layout': 'normal',
#     'multiverse_id': 397878,
#     'number': '169',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'rare',
#     'set': 'Modern Masters 2015 Edition',
#     'set_id': 'MM2',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/MM2',
#     'store_url': 'http://store.tcgplayer.com/magic/modern-masters-2015-edition/wolfbriar-elemental?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=397878'},
#    {'artist': 'Chippy',
#     'html_url': 'https://deckbrew.com/mtg/cards/189162',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/189162.jpg',
#     'layout': 'normal',
#     'multiverse_id': 189162,
#     'number': '118',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'rare',
#     'set': 'Worldwake',
#     'set_id': 'WWK',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/WWK',
#     'store_url': 'http://store.tcgplayer.com/magic/worldwake/wolfbriar-elemental?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=189162'},
#    {'artist': 'Chippy',
#     'html_url': 'https://deckbrew.com/mtg/cards/382408',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/382408.jpg',
#     'layout': 'normal',
#     'multiverse_id': 382408,
#     'number': '182',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'rare',
#     'set': 'Magic: The Gathering—Conspiracy',
#     'set_id': 'CNS',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/CNS',
#     'store_url': 'http://store.tcgplayer.com/magic/conspiracy/wolfbriar-elemental?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=382408'},
#    {'artist': 'Chippy',
#     'html_url': 'https://deckbrew.com/mtg/cards/430387',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/430387.jpg',
#     'layout': 'normal',
#     'multiverse_id': 430387,
#     'number': '168',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'rare',
#     'set': 'Commander Anthology',
#     'set_id': 'CMA',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/CMA',
#     'store_url': 'http://store.tcgplayer.com/magic/commander-anthology/wolfbriar-elemental?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=430387'}],
#   'formats': {'commander': 'legal',
#    'legacy': 'legal',
#    'modern': 'legal',
#    'vintage': 'legal'},
#   'id': 'wolfbriar-elemental',
#   'name': 'Wolfbriar Elemental',
#   'power': '4',
#   'store_url': 'http://store.tcgplayer.com/magic/product/show?partner=DECKBREW&ProductName=wolfbriar-elemental',
#   'subtypes': ['elemental'],
#   'text': 'Multikicker {G} (You may pay an additional {G} any number of times as you cast this spell.)\nWhen Wolfbriar Elemental enters the battlefield, create a 2/2 green Wolf creature token for each time it was kicked.',
#   'toughness': '4',
#   'types': ['creature'],
#   'url': 'https://api.deckbrew.com/mtg/cards/wolfbriar-elemental'},
#  {'cmc': 1,
#   'cost': '{1}',
#   'editions': [{'artist': 'Daniel Ljunggren',
#     'flavor': '"Steel in the heart, silver in the bow."\n—Wolfhunter\'s creed',
#     'html_url': 'https://deckbrew.com/mtg/cards/247124',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/247124.jpg',
#     'layout': 'normal',
#     'multiverse_id': 247124,
#     'number': '154',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'uncommon',
#     'set': 'Dark Ascension',
#     'set_id': 'DKA',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/DKA',
#     'store_url': 'http://store.tcgplayer.com/magic/dark-ascension/wolfhunters-quiver?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=247124'}],
#   'formats': {'commander': 'legal',
#    'legacy': 'legal',
#    'modern': 'legal',
#    'vintage': 'legal'},
#   'id': 'wolfhunters-quiver',
#   'name': "Wolfhunter's Quiver",
#   'store_url': 'http://store.tcgplayer.com/magic/dark-ascension/wolfhunters-quiver?partner=DECKBREW',
#   'subtypes': ['equipment'],
#   'text': 'Equipped creature has "{T}: This creature deals 1 damage to target creature or player" and "{T}: This creature deals 3 damage to target Werewolf creature."\nEquip {5}',
#   'types': ['artifact'],
#   'url': 'https://api.deckbrew.com/mtg/cards/wolfhunters-quiver'},
#  {'cmc': 3,
#   'colors': ['green'],
#   'cost': '{1}{G}{G}',
#   'editions': [{'artist': 'Daniel Ljunggren',
#     'flavor': 'Released from a dark curse and bound to a higher calling.',
#     'html_url': 'https://deckbrew.com/mtg/cards/276501',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/276501.jpg',
#     'layout': 'normal',
#     'multiverse_id': 276501,
#     'number': '205',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'uncommon',
#     'set': 'Avacyn Restored',
#     'set_id': 'AVR',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/AVR',
#     'store_url': 'http://store.tcgplayer.com/magic/avacyn-restored/wolfir-avenger?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=276501'}],
#   'formats': {'commander': 'legal',
#    'legacy': 'legal',
#    'modern': 'legal',
#    'vintage': 'legal'},
#   'id': 'wolfir-avenger',
#   'name': 'Wolfir Avenger',
#   'power': '3',
#   'store_url': 'http://store.tcgplayer.com/magic/avacyn-restored/wolfir-avenger?partner=DECKBREW',
#   'subtypes': ['warrior', 'wolf'],
#   'text': 'Flash (You may cast this spell any time you could cast an instant.)\n{1}{G}: Regenerate Wolfir Avenger.',
#   'toughness': '3',
#   'types': ['creature'],
#   'url': 'https://api.deckbrew.com/mtg/cards/wolfir-avenger'},
#  {'cmc': 5,
#   'colors': ['green'],
#   'cost': '{3}{G}{G}',
#   'editions': [{'artist': 'Raymond Swanland',
#     'html_url': 'https://deckbrew.com/mtg/cards/240090',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/240090.jpg',
#     'layout': 'normal',
#     'multiverse_id': 240090,
#     'number': '206',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'rare',
#     'set': 'Avacyn Restored',
#     'set_id': 'AVR',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/AVR',
#     'store_url': 'http://store.tcgplayer.com/magic/avacyn-restored/wolfir-silverheart?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=240090'}],
#   'formats': {'commander': 'legal',
#    'legacy': 'legal',
#    'modern': 'legal',
#    'vintage': 'legal'},
#   'id': 'wolfir-silverheart',
#   'name': 'Wolfir Silverheart',
#   'power': '4',
#   'store_url': 'http://store.tcgplayer.com/magic/avacyn-restored/wolfir-silverheart?partner=DECKBREW',
#   'subtypes': ['warrior', 'wolf'],
#   'text': 'Soulbond (You may pair this creature with another unpaired creature when either enters the battlefield. They remain paired for as long as you control both of them.)\nAs long as Wolfir Silverheart is paired with another creature, each of those creatures gets +4/+4.',
#   'toughness': '4',
#   'types': ['creature'],
#   'url': 'https://api.deckbrew.com/mtg/cards/wolfir-silverheart'},
#  {'cmc': 5,
#   'colors': ['green'],
#   'cost': '{4}{G}',
#   'editions': [{'artist': 'Lindsey Look',
#     'html_url': 'https://deckbrew.com/mtg/cards/414483',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/414483.jpg',
#     'layout': 'normal',
#     'multiverse_id': 414483,
#     'number': '178',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'common',
#     'set': 'Eldritch Moon',
#     'set_id': 'EMN',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/EMN',
#     'store_url': 'http://store.tcgplayer.com/magic/eldritch-moon/wolfkin-bond?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=414483'}],
#   'formats': {'commander': 'legal',
#    'legacy': 'legal',
#    'modern': 'legal',
#    'vintage': 'legal'},
#   'id': 'wolfkin-bond',
#   'name': 'Wolfkin Bond',
#   'store_url': 'http://store.tcgplayer.com/magic/eldritch-moon/wolfkin-bond?partner=DECKBREW',
#   'subtypes': ['aura'],
#   'text': 'Enchant creature\nWhen Wolfkin Bond enters the battlefield, Create a 2/2 green Wolf creature token.\nEnchanted creature gets +2/+2.',
#   'types': ['enchantment'],
#   'url': 'https://api.deckbrew.com/mtg/cards/wolfkin-bond'},
#  {'cmc': 5,
#   'colors': ['red'],
#   'cost': '{3}{R}{R}',
#   'editions': [{'artist': 'Jack Wang',
#     'flavor': '"How can werewolves be considered abominations next to such creatures?"\n—Arlinn Kord',
#     'html_url': 'https://deckbrew.com/mtg/cards/409949',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/409949.jpg',
#     'layout': 'normal',
#     'multiverse_id': 409949,
#     'number': '192',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'mythic',
#     'set': 'Shadows over Innistrad',
#     'set_id': 'SOI',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/SOI',
#     'store_url': 'http://store.tcgplayer.com/magic/shadows-over-innistrad/wolf-of-devils-breach?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=409949'}],
#   'formats': {'commander': 'legal',
#    'legacy': 'legal',
#    'modern': 'legal',
#    'vintage': 'legal'},
#   'id': 'wolf-of-devils-breach',
#   'name': "Wolf of Devil's Breach",
#   'power': '5',
#   'store_url': 'http://store.tcgplayer.com/magic/shadows-over-innistrad/wolf-of-devils-breach?partner=DECKBREW',
#   'subtypes': ['elemental', 'wolf'],
#   'text': "Whenever Wolf of Devil's Breach attacks, you may pay {1}{R} and discard a card. If you do, Wolf of Devil's Breach deals damage to target creature or planeswalker equal to the discarded card's converted mana cost.",
#   'toughness': '5',
#   'types': ['creature'],
#   'url': 'https://api.deckbrew.com/mtg/cards/wolf-of-devils-breach'},
#  {'cmc': 2,
#   'colors': ['green'],
#   'cost': '{1}{G}',
#   'editions': [{'artist': 'Jim Murray',
#     'flavor': 'A chorus of howls answers his call.',
#     'html_url': 'https://deckbrew.com/mtg/cards/152728',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/152728.jpg',
#     'layout': 'normal',
#     'multiverse_id': 152728,
#     'number': '140',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'uncommon',
#     'set': 'Morningtide',
#     'set_id': 'MOR',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/MOR',
#     'store_url': 'http://store.tcgplayer.com/magic/morningtide/wolf-skull-shaman?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=152728'}],
#   'formats': {'commander': 'legal',
#    'legacy': 'legal',
#    'modern': 'legal',
#    'vintage': 'legal'},
#   'id': 'wolf-skull-shaman',
#   'name': 'Wolf-Skull Shaman',
#   'power': '2',
#   'store_url': 'http://store.tcgplayer.com/magic/morningtide/wolf-skull-shaman?partner=DECKBREW',
#   'subtypes': ['elf', 'shaman'],
#   'text': 'Kinship — At the beginning of your upkeep, you may look at the top card of your library. If it shares a creature type with Wolf-Skull Shaman, you may reveal it. If you do, create a 2/2 green Wolf creature token.',
#   'toughness': '2',
#   'types': ['creature'],
#   'url': 'https://api.deckbrew.com/mtg/cards/wolf-skull-shaman'},
#  {'cmc': 5,
#   'colors': ['green'],
#   'cost': '{3}{G}{G}',
#   'editions': [{'artist': 'Matt Stewart',
#     'flavor': "It carries the hopes of Zendikar's embattled wilds on its mighty boughs.",
#     'html_url': 'https://deckbrew.com/mtg/cards/417449',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/417449.jpg',
#     'layout': 'normal',
#     'multiverse_id': 417449,
#     'number': '26',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'uncommon',
#     'set': 'Duel Decks: Nissa vs. Ob Nixilis',
#     'set_id': 'DDR',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/DDR',
#     'store_url': 'http://store.tcgplayer.com/magic/duel-decks-nissa-vs-ob-nixilis/woodborn-behemoth?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=417449'},
#    {'artist': 'Matt Stewart',
#     'flavor': "It carries the hopes of Zendikar's embattled wilds on its mighty boughs.",
#     'html_url': 'https://deckbrew.com/mtg/cards/430618',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/430618.jpg',
#     'layout': 'normal',
#     'multiverse_id': 430618,
#     'number': '79',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'uncommon',
#     'set': 'Archenemy: Nicol Bolas',
#     'set_id': 'E01',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/E01',
#     'store_url': 'http://store.tcgplayer.com/magic/archenemy-nicol-bolas/woodborn-behemoth?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=430618'},
#    {'artist': 'Matt Stewart',
#     'html_url': 'https://deckbrew.com/mtg/cards/370665',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/370665.jpg',
#     'layout': 'normal',
#     'multiverse_id': 370665,
#     'number': '203',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'uncommon',
#     'set': 'Magic 2014 Core Set',
#     'set_id': 'M14',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/M14',
#     'store_url': 'http://store.tcgplayer.com/magic/magic-2014-(m14)/woodborn-behemoth?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=370665'}],
#   'formats': {'commander': 'legal',
#    'legacy': 'legal',
#    'modern': 'legal',
#    'vintage': 'legal'},
#   'id': 'woodborn-behemoth',
#   'name': 'Woodborn Behemoth',
#   'power': '4',
#   'store_url': 'http://store.tcgplayer.com/magic/product/show?partner=DECKBREW&ProductName=woodborn-behemoth',
#   'subtypes': ['elemental'],
#   'text': 'As long as you control eight or more lands, Woodborn Behemoth gets +4/+4 and has trample. (If this creature would assign enough damage to its blockers to destroy them, you may have it assign the rest of its damage to defending player or planeswalker.)',
#   'toughness': '4',
#   'types': ['creature'],
#   'url': 'https://api.deckbrew.com/mtg/cards/woodborn-behemoth'},
#  {'cmc': 3,
#   'colors': ['green'],
#   'cost': '{2}{G}',
#   'editions': [{'artist': 'Anthony Palumbo',
#     'flavor': 'The magic used by Kessigers is known for its practical applications.',
#     'html_url': 'https://deckbrew.com/mtg/cards/414484',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/414484.jpg',
#     'layout': 'normal',
#     'multiverse_id': 414484,
#     'number': '179',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'common',
#     'set': 'Eldritch Moon',
#     'set_id': 'EMN',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/EMN',
#     'store_url': 'http://store.tcgplayer.com/magic/eldritch-moon/woodcutters-grit?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=414484'}],
#   'formats': {'commander': 'legal',
#    'legacy': 'legal',
#    'modern': 'legal',
#    'vintage': 'legal'},
#   'id': 'woodcutters-grit',
#   'name': "Woodcutter's Grit",
#   'store_url': 'http://store.tcgplayer.com/magic/eldritch-moon/woodcutters-grit?partner=DECKBREW',
#   'text': "Target creature you control gets +3/+3 and gains hexproof until end of turn. (It can't be the target of spells or abilities your opponents control.)",
#   'types': ['instant'],
#   'url': 'https://api.deckbrew.com/mtg/cards/woodcutters-grit'},
#  {'cmc': 0,
#   'cost': '',
#   'editions': [{'artist': 'Christopher Moeller',
#     'flavor': 'The elves of Wilt-Leaf Wood continually expand the palisade surrounding the sanctuary. They hope to one day enclose the entire forest within its walls.',
#     'html_url': 'https://deckbrew.com/mtg/cards/146747',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/146747.jpg',
#     'layout': 'normal',
#     'multiverse_id': 146747,
#     'number': '281',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'rare',
#     'set': 'Shadowmoor',
#     'set_id': 'SHM',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/SHM',
#     'store_url': 'http://store.tcgplayer.com/magic/shadowmoor/wooded-bastion?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=146747'},
#    {'artist': 'Adam Paquette',
#     'html_url': 'https://deckbrew.com/mtg/cards/409561',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/409561.jpg',
#     'layout': 'normal',
#     'multiverse_id': 409561,
#     'number': '30',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'mythic',
#     'set': 'Zendikar Expeditions',
#     'set_id': 'EXP',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/EXP',
#     'store_url': 'http://store.tcgplayer.com/magic/zendikar-expeditions/wooded-bastion?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=409561'}],
#   'formats': {'commander': 'legal',
#    'legacy': 'legal',
#    'modern': 'legal',
#    'vintage': 'legal'},
#   'id': 'wooded-bastion',
#   'name': 'Wooded Bastion',
#   'store_url': 'http://store.tcgplayer.com/magic/product/show?partner=DECKBREW&ProductName=wooded-bastion',
#   'text': '{T}: Add {C} to your mana pool.\n{G/W}, {T}: Add {G}{G}, {G}{W}, or {W}{W} to your mana pool.',
#   'types': ['land'],
#   'url': 'https://api.deckbrew.com/mtg/cards/wooded-bastion'},
#  {'cmc': 0,
#   'cost': '',
#   'editions': [{'artist': 'Rob Alexander',
#     'html_url': 'https://deckbrew.com/mtg/cards/0',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/0.jpg',
#     'layout': 'normal',
#     'multiverse_id': 0,
#     'number': '47',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'special',
#     'set': 'Judge Gift Program',
#     'set_id': 'pJGP',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/pJGP',
#     'store_url': 'http://store.tcgplayer.com/magic/judge-gift-program/wooded-foothills?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=0'},
#    {'artist': 'Rob Alexander',
#     'html_url': 'https://deckbrew.com/mtg/cards/39506',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/39506.jpg',
#     'layout': 'normal',
#     'multiverse_id': 39506,
#     'number': '330',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'rare',
#     'set': 'Onslaught',
#     'set_id': 'ONS',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/ONS',
#     'store_url': 'http://store.tcgplayer.com/magic/onslaught/wooded-foothills?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=39506'},
#    {'artist': 'Jonas De Ro',
#     'flavor': "Where dragons' breath once burned, their bones now freeze.",
#     'html_url': 'https://deckbrew.com/mtg/cards/386729',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/386729.jpg',
#     'layout': 'normal',
#     'multiverse_id': 386729,
#     'number': '249',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'rare',
#     'set': 'Khans of Tarkir',
#     'set_id': 'KTK',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/KTK',
#     'store_url': 'http://store.tcgplayer.com/magic/khans-of-tarkir/wooded-foothills?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=386729'},
#    {'artist': 'Véronique Meignaud',
#     'html_url': 'https://deckbrew.com/mtg/cards/405116',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/405116.jpg',
#     'layout': 'normal',
#     'multiverse_id': 405116,
#     'number': '19',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'mythic',
#     'set': 'Zendikar Expeditions',
#     'set_id': 'EXP',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/EXP',
#     'store_url': 'http://store.tcgplayer.com/magic/zendikar-expeditions/wooded-foothills?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=405116'}],
#   'formats': {'commander': 'legal',
#    'legacy': 'legal',
#    'modern': 'legal',
#    'vintage': 'legal'},
#   'id': 'wooded-foothills',
#   'name': 'Wooded Foothills',
#   'store_url': 'http://store.tcgplayer.com/magic/product/show?partner=DECKBREW&ProductName=wooded-foothills',
#   'text': '{T}, Pay 1 life, Sacrifice Wooded Foothills: Search your library for a Mountain or Forest card and put it onto the battlefield. Then shuffle your library.',
#   'types': ['land'],
#   'url': 'https://api.deckbrew.com/mtg/cards/wooded-foothills'},
#  {'cmc': 3,
#   'colors': ['green'],
#   'cost': '{2}{G}',
#   'editions': [{'artist': 'Josh Hass',
#     'flavor': 'Through the waves of Eldrazi attacks, the Murasan jungles seemed to regrow as soon as they were destroyed.',
#     'html_url': 'https://deckbrew.com/mtg/cards/417448',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/417448.jpg',
#     'layout': 'normal',
#     'multiverse_id': 417448,
#     'number': '25',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'common',
#     'set': 'Duel Decks: Nissa vs. Ob Nixilis',
#     'set_id': 'DDR',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/DDR',
#     'store_url': 'http://store.tcgplayer.com/magic/duel-decks-nissa-vs-ob-nixilis/wood-elves?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=417448'},
#    {'artist': 'Christopher Moeller',
#     'flavor': 'Every branch a crossroads, every vine a swift steed.',
#     'html_url': 'https://deckbrew.com/mtg/cards/394001',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/394001.jpg',
#     'layout': 'normal',
#     'multiverse_id': 394001,
#     'number': '18',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'common',
#     'set': 'Duel Decks Anthology, Elves vs. Goblins',
#     'set_id': 'DD3_EVG',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/DD3_EVG',
#     'store_url': 'http://store.tcgplayer.com/magic/duel-decks-anthology-elves-vs-goblins/wood-elves?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=394001'},
#    {'artist': 'Christopher Moeller',
#     'flavor': 'Every branch a crossroads, every vine a swift steed.',
#     'html_url': 'https://deckbrew.com/mtg/cards/45400',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/45400.jpg',
#     'layout': 'normal',
#     'multiverse_id': 45400,
#     'number': '289',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'common',
#     'set': 'Eighth Edition',
#     'set_id': '8ED',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/8ED',
#     'store_url': 'http://store.tcgplayer.com/magic/8th-edition/wood-elves?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=45400'},
#    {'artist': 'Christopher Moeller',
#     'flavor': 'Every branch a crossroads, every vine a swift steed.',
#     'html_url': 'https://deckbrew.com/mtg/cards/389752',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/389752.jpg',
#     'layout': 'normal',
#     'multiverse_id': 389752,
#     'number': '226',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'common',
#     'set': 'Commander 2014',
#     'set_id': 'C14',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/C14',
#     'store_url': 'http://store.tcgplayer.com/magic/commander-2014/wood-elves?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=389752'},
#    {'artist': 'Rebecca Guay',
#     'html_url': 'https://deckbrew.com/mtg/cards/20224',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/20224.jpg',
#     'layout': 'normal',
#     'multiverse_id': 20224,
#     'number': '153',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'uncommon',
#     'set': 'Starter 1999',
#     'set_id': 'S99',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/S99',
#     'store_url': 'http://store.tcgplayer.com/magic/starter-1999/wood-elves?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=20224'},
#    {'artist': 'Christopher Moeller',
#     'flavor': 'Every branch a crossroads, every vine a swift steed.',
#     'html_url': 'https://deckbrew.com/mtg/cards/405454',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/405454.jpg',
#     'layout': 'normal',
#     'multiverse_id': 405454,
#     'number': '212',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'common',
#     'set': 'Commander 2015',
#     'set_id': 'C15',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/C15',
#     'store_url': 'http://store.tcgplayer.com/magic/commander-2015/wood-elves?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=405454'},
#    {'artist': 'Christopher Moeller',
#     'flavor': 'Every branch a crossroads, every vine a swift steed.',
#     'html_url': 'https://deckbrew.com/mtg/cards/83336',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/83336.jpg',
#     'layout': 'normal',
#     'multiverse_id': 83336,
#     'number': '283',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'common',
#     'set': 'Ninth Edition',
#     'set_id': '9ED',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/9ED',
#     'store_url': 'http://store.tcgplayer.com/magic/9th-edition/wood-elves?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=83336'},
#    {'artist': 'Rebecca Guay',
#     'flavor': "Secure in the embrace of wood, they want no part of Eladamri's war.",
#     'html_url': 'https://deckbrew.com/mtg/cards/6135',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/6135.jpg',
#     'layout': 'normal',
#     'multiverse_id': 6135,
#     'number': '130',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'common',
#     'set': 'Exodus',
#     'set_id': 'EXO',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/EXO',
#     'store_url': 'http://store.tcgplayer.com/magic/exodus/wood-elves?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=6135'},
#    {'artist': 'Rebecca Guay',
#     'flavor': 'Every branch a crossroads, every vine a swift steed.',
#     'html_url': 'https://deckbrew.com/mtg/cards/0',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/0.jpg',
#     'layout': 'normal',
#     'multiverse_id': 0,
#     'number': '1',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'special',
#     'set': 'Gateway',
#     'set_id': 'pGTW',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/pGTW',
#     'store_url': 'http://store.tcgplayer.com/magic/gateway/wood-elves?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=0'},
#    {'artist': 'Rebecca Guay',
#     'html_url': 'https://deckbrew.com/mtg/cards/4327',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/4327.jpg',
#     'layout': 'normal',
#     'multiverse_id': 4327,
#     'number': '',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'rare',
#     'set': 'Portal',
#     'set_id': 'POR',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/POR',
#     'store_url': 'http://store.tcgplayer.com/magic/portal/wood-elves?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=4327'},
#    {'artist': 'Christopher Moeller',
#     'flavor': 'Every branch a crossroads, every vine a swift steed.',
#     'html_url': 'https://deckbrew.com/mtg/cards/13147',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/13147.jpg',
#     'layout': 'normal',
#     'multiverse_id': 13147,
#     'number': '284',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'common',
#     'set': 'Seventh Edition',
#     'set_id': '7ED',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/7ED',
# ...
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=140229'}],
#   'formats': {'commander': 'legal',
#    'legacy': 'legal',
#    'modern': 'legal',
#    'vintage': 'legal'},
#   'id': 'wydwen-the-biting-gale',
#   'name': 'Wydwen, the Biting Gale',
#   'power': '3',
#   'store_url': 'http://store.tcgplayer.com/magic/lorwyn/wydwen-the-biting-gale?partner=DECKBREW',
#   'subtypes': ['faerie', 'wizard'],
#   'supertypes': ['legendary'],
#   'text': "Flash\nFlying\n{U}{B}, Pay 1 life: Return Wydwen, the Biting Gale to its owner's hand.",
#   'toughness': '3',
#   'types': ['creature'],
#   'url': 'https://api.deckbrew.com/mtg/cards/wydwen-the-biting-gale'},
#  {'cmc': 6,
#   'colors': ['black'],
#   'cost': '{3}{B}{B}{B}',
#   'editions': [{'artist': 'Wayne Reynolds',
#     'html_url': 'https://deckbrew.com/mtg/cards/389757',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/389757.jpg',
#     'layout': 'normal',
#     'multiverse_id': 389757,
#     'number': '170',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'mythic',
#     'set': 'Commander 2014',
#     'set_id': 'C14',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/C14',
#     'store_url': 'http://store.tcgplayer.com/magic/commander-2014/xathrid-demon?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=389757'},
#    {'artist': 'Wayne Reynolds',
#     'html_url': 'https://deckbrew.com/mtg/cards/189885',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/189885.jpg',
#     'layout': 'normal',
#     'multiverse_id': 189885,
#     'number': '122',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'mythic',
#     'set': 'Magic 2010',
#     'set_id': 'M10',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/M10',
#     'store_url': 'http://store.tcgplayer.com/magic/magic-2010-(m10)/xathrid-demon?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=189885'}],
#   'formats': {'commander': 'legal',
#    'legacy': 'legal',
#    'modern': 'legal',
#    'vintage': 'legal'},
#   'id': 'xathrid-demon',
#   'name': 'Xathrid Demon',
#   'power': '7',
#   'store_url': 'http://store.tcgplayer.com/magic/product/show?partner=DECKBREW&ProductName=xathrid-demon',
#   'subtypes': ['demon'],
#   'text': "Flying, trample\nAt the beginning of your upkeep, sacrifice a creature other than Xathrid Demon, then each opponent loses life equal to the sacrificed creature's power. If you can't sacrifice a creature, tap Xathrid Demon and you lose 7 life.",
#   'toughness': '7',
#   'types': ['creature'],
#   'url': 'https://api.deckbrew.com/mtg/cards/xathrid-demon'},
#  {'cmc': 6,
#   'colors': ['black'],
#   'cost': '{5}{B}',
#   'editions': [{'artist': 'Wesley Burt',
#     'html_url': 'https://deckbrew.com/mtg/cards/0',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/0.jpg',
#     'layout': 'normal',
#     'multiverse_id': 0,
#     'number': '54',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'special',
#     'set': 'Prerelease Events',
#     'set_id': 'pPRE',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/pPRE',
#     'store_url': 'http://store.tcgplayer.com/magic/prerelease-events/xathrid-gorgon?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=0'},
#    {'artist': 'Chase Stone',
#     'html_url': 'https://deckbrew.com/mtg/cards/253728',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/253728.jpg',
#     'layout': 'normal',
#     'multiverse_id': 253728,
#     'number': '118',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'rare',
#     'set': 'Magic 2013',
#     'set_id': 'M13',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/M13',
#     'store_url': 'http://store.tcgplayer.com/magic/magic-2013-(m13)/xathrid-gorgon?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=253728'}],
#   'formats': {'commander': 'legal',
#    'legacy': 'legal',
#    'modern': 'legal',
#    'vintage': 'legal'},
#   'id': 'xathrid-gorgon',
#   'name': 'Xathrid Gorgon',
#   'power': '3',
#   'store_url': 'http://store.tcgplayer.com/magic/product/show?partner=DECKBREW&ProductName=xathrid-gorgon',
#   'subtypes': ['gorgon'],
#   'text': "Deathtouch (Any amount of damage this deals to a creature is enough to destroy it.)\n{2}{B}, {T}: Put a petrification counter on target creature. It gains defender and becomes a colorless artifact in addition to its other types. Its activated abilities can't be activated. (A creature with defender can't attack.)",
#   'toughness': '6',
#   'types': ['creature'],
#   'url': 'https://api.deckbrew.com/mtg/cards/xathrid-gorgon'},
#  {'cmc': 3,
#   'colors': ['black'],
#   'cost': '{2}{B}',
#   'editions': [{'artist': 'Maciej Kuciara',
#     'flavor': '"My commands shall echo forever in their dusty skulls."',
#     'html_url': 'https://deckbrew.com/mtg/cards/0',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/0.jpg',
#     'layout': 'normal',
#     'multiverse_id': 0,
#     'number': '91',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'special',
#     'set': 'Media Inserts',
#     'set_id': 'pMEI',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/pMEI',
#     'store_url': 'http://store.tcgplayer.com/magic/media-inserts/xathrid-necromancer?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=0'},
#    {'artist': 'Maciej Kuciara',
#     'flavor': '"My commands shall echo forever in their dusty skulls."',
#     'html_url': 'https://deckbrew.com/mtg/cards/370619',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/370619.jpg',
#     'layout': 'normal',
#     'multiverse_id': 370619,
#     'number': '123',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'rare',
#     'set': 'Magic 2014 Core Set',
#     'set_id': 'M14',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/M14',
#     'store_url': 'http://store.tcgplayer.com/magic/magic-2014-(m14)/xathrid-necromancer?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=370619'}],
#   'formats': {'commander': 'legal',
#    'legacy': 'legal',
#    'modern': 'legal',
#    'vintage': 'legal'},
#   'id': 'xathrid-necromancer',
#   'name': 'Xathrid Necromancer',
#   'power': '2',
#   'store_url': 'http://store.tcgplayer.com/magic/product/show?partner=DECKBREW&ProductName=xathrid-necromancer',
#   'subtypes': ['human', 'wizard'],
#   'text': 'Whenever Xathrid Necromancer or another Human creature you control dies, create a tapped 2/2 black Zombie creature token.',
#   'toughness': '2',
#   'types': ['creature'],
#   'url': 'https://api.deckbrew.com/mtg/cards/xathrid-necromancer'},
#  {'cmc': 3,
#   'colors': ['black'],
#   'cost': '{2}{B}',
#   'editions': [{'artist': 'Steve Prescott',
#     'flavor': 'Designed by Rob Pardo',
#     'html_url': 'https://deckbrew.com/mtg/cards/383440',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/383440.jpg',
#     'layout': 'normal',
#     'multiverse_id': 383440,
#     'number': '124',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'uncommon',
#     'set': 'Magic 2015 Core Set',
#     'set_id': 'M15',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/M15',
#     'store_url': 'http://store.tcgplayer.com/magic/magic-2015-(m15)/xathrid-slyblade?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=383440'}],
#   'formats': {'commander': 'legal',
#    'legacy': 'legal',
#    'modern': 'legal',
#    'vintage': 'legal'},
#   'id': 'xathrid-slyblade',
#   'name': 'Xathrid Slyblade',
#   'power': '2',
#   'store_url': 'http://store.tcgplayer.com/magic/magic-2015-(m15)/xathrid-slyblade?partner=DECKBREW',
#   'subtypes': ['assassin', 'human'],
#   'text': "Hexproof (This creature can't be the target of spells or abilities your opponents control.)\n{3}{B}: Until end of turn, Xathrid Slyblade loses hexproof and gains first strike and deathtouch. (It deals combat damage before creatures without first strike. Any amount of damage it deals to a creature is enough to destroy it.)",
#   'toughness': '1',
#   'types': ['creature'],
#   'url': 'https://api.deckbrew.com/mtg/cards/xathrid-slyblade'},
#  {'cmc': 5,
#   'colors': ['green', 'red'],
#   'cost': '{3}{R}{G}',
#   'editions': [{'artist': 'Jason Chan',
#     'html_url': 'https://deckbrew.com/mtg/cards/378528',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/378528.jpg',
#     'layout': 'normal',
#     'multiverse_id': 378528,
#     'number': '156',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'mythic',
#     'set': 'Born of the Gods',
#     'set_id': 'BNG',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/BNG',
#     'store_url': 'http://store.tcgplayer.com/magic/born-of-the-gods/xenagos-god-of-revels?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=378528'}],
#   'formats': {'commander': 'legal',
#    'legacy': 'legal',
#    'modern': 'legal',
#    'vintage': 'legal'},
#   'id': 'xenagos-god-of-revels',
#   'name': 'Xenagos, God of Revels',
#   'power': '6',
#   'store_url': 'http://store.tcgplayer.com/magic/born-of-the-gods/xenagos-god-of-revels?partner=DECKBREW',
#   'subtypes': ['god'],
#   'supertypes': ['legendary'],
#   'text': "Indestructible\nAs long as your devotion to red and green is less than seven, Xenagos isn't a creature.\nAt the beginning of combat on your turn, another target creature you control gains haste and gets +X/+X until end of turn, where X is that creature's power.",
#   'toughness': '5',
#   'types': ['creature', 'enchantment'],
#   'url': 'https://api.deckbrew.com/mtg/cards/xenagos-god-of-revels'},
#  {'cmc': 4,
#   'colors': ['green', 'red'],
#   'cost': '{2}{R}{G}',
#   'editions': [{'artist': 'Jason Chan',
#     'html_url': 'https://deckbrew.com/mtg/cards/373502',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/373502.jpg',
#     'layout': 'normal',
#     'multiverse_id': 373502,
#     'number': '209',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'mythic',
#     'set': 'Theros',
#     'set_id': 'THS',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/THS',
#     'store_url': 'http://store.tcgplayer.com/magic/theros/xenagos-the-reveler?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=373502'}],
#   'formats': {'commander': 'legal',
#    'legacy': 'legal',
#    'modern': 'legal',
#    'vintage': 'legal'},
#   'id': 'xenagos-the-reveler',
#   'loyalty': 3,
#   'name': 'Xenagos, the Reveler',
#   'store_url': 'http://store.tcgplayer.com/magic/theros/xenagos-the-reveler?partner=DECKBREW',
#   'subtypes': ['xenagos'],
#   'supertypes': ['legendary'],
#   'text': '+1: Add X mana in any combination of {R} and/or {G} to your mana pool, where X is the number of creatures you control.\n0: Create a 2/2 red and green Satyr creature token with haste.\n−6: Exile the top seven cards of your library. You may put any number of creature and/or land cards from among them onto the battlefield.',
#   'types': ['planeswalker'],
#   'url': 'https://api.deckbrew.com/mtg/cards/xenagos-the-reveler'},
#  {'cmc': 5,
#   'colors': ['blue'],
#   'cost': '{4}{U}',
#   'editions': [{'artist': 'Daniel Ljunggren',
#     'flavor': '"I despise Vorinclex and his slobberings about \'evolution.\' Only I know true progress."\n—Jin-Gitaxias, Core Augur',
#     'html_url': 'https://deckbrew.com/mtg/cards/227544',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/227544.jpg',
#     'layout': 'normal',
#     'multiverse_id': 227544,
#     'number': '51',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'rare',
#     'set': 'New Phyrexia',
#     'set_id': 'NPH',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/NPH',
#     'store_url': 'http://store.tcgplayer.com/magic/new-phyrexia/xenograft?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=227544',
#     'watermark': 'Phyrexian'}],
#   'formats': {'commander': 'legal',
#    'legacy': 'legal',
#    'modern': 'legal',
#    'vintage': 'legal'},
#   'id': 'xenograft',
#   'name': 'Xenograft',
#   'store_url': 'http://store.tcgplayer.com/magic/new-phyrexia/xenograft?partner=DECKBREW',
#   'text': 'As Xenograft enters the battlefield, choose a creature type.\nEach creature you control is the chosen type in addition to its other types.',
#   'types': ['enchantment'],
#   'url': 'https://api.deckbrew.com/mtg/cards/xenograft'},
#  {'cmc': 4,
#   'colors': ['black'],
#   'cost': '{2}{B}{B}',
#   'editions': [{'artist': 'Daarken',
#     'flavor': '"The Consulate pushed me to my limit, darling, and this is the result."',
#     'html_url': 'https://deckbrew.com/mtg/cards/423742',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/423742.jpg',
#     'layout': 'normal',
#     'multiverse_id': 423742,
#     'number': '75',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'rare',
#     'set': 'Aether Revolt',
#     'set_id': 'AER',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/AER',
#     'store_url': 'http://store.tcgplayer.com/magic/aether-revolt/yahennis-expertise?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=423742'}],
#   'formats': {'commander': 'legal',
#    'legacy': 'legal',
#    'modern': 'legal',
#    'standard': 'legal',
#    'vintage': 'legal'},
#   'id': 'yahennis-expertise',
#   'name': "Yahenni's Expertise",
#   'store_url': 'http://store.tcgplayer.com/magic/aether-revolt/yahennis-expertise?partner=DECKBREW',
#   'text': 'All creatures get -3/-3 until end of turn.\nYou may cast a card with converted mana cost 3 or less from your hand without paying its mana cost.',
#   'types': ['sorcery'],
#   'url': 'https://api.deckbrew.com/mtg/cards/yahennis-expertise'},
#  {'cmc': 3,
#   'colors': ['black'],
#   'cost': '{2}{B}',
#   'editions': [{'artist': 'Lius Lasahido',
#     'flavor': '"The time for subtlety is over, darling."',
#     'html_url': 'https://deckbrew.com/mtg/cards/423741',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/423741.jpg',
#     'layout': 'normal',
#     'multiverse_id': 423741,
#     'number': '74',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'rare',
#     'set': 'Aether Revolt',
#     'set_id': 'AER',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/AER',
#     'store_url': 'http://store.tcgplayer.com/magic/aether-revolt/yahenni-undying-partisan?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=423741'}],
#   'formats': {'commander': 'legal',
#    'legacy': 'legal',
#    'modern': 'legal',
#    'standard': 'legal',
#    'vintage': 'legal'},
#   'id': 'yahenni-undying-partisan',
#   'name': 'Yahenni, Undying Partisan',
#   'power': '2',
#   'store_url': 'http://store.tcgplayer.com/magic/aether-revolt/yahenni-undying-partisan?partner=DECKBREW',
#   'subtypes': ['aetherborn', 'vampire'],
#   'supertypes': ['legendary'],
#   'text': 'Haste\nWhenever a creature an opponent controls dies, put a +1/+1 counter on Yahenni, Undying Partisan.\nSacrifice another creature: Yahenni gains indestructible until end of turn.',
#   'toughness': '2',
#   'types': ['creature'],
#   'url': 'https://api.deckbrew.com/mtg/cards/yahenni-undying-partisan'},
#  {'cmc': 3,
#   'colors': ['red'],
#   'cost': '{2}{R}',
#   'editions': [{'artist': 'Christopher Moeller',
#     'html_url': 'https://deckbrew.com/mtg/cards/50292',
#     'image_url': 'https://image.deckbrew.com/mtg/multiverseid/50292.jpg',
#     'layout': 'normal',
#     'multiverse_id': 50292,
#     'number': '198',
#     'price': {'high': 0, 'low': 0, 'median': 0},
#     'rarity': 'common',
#     'set': 'Champions of Kamigawa',
#     'set_id': 'CHK',
#     'set_url': 'https://api.deckbrew.com/mtg/sets/CHK',
#     'store_url': 'http://store.tcgplayer.com/magic/champions-of-kamigawa/yamabushis-flame?partner=DECKBREW',
#     'url': 'https://api.deckbrew.com/mtg/cards?multiverseid=50292'}],
#   'formats': {'commander': 'legal',
#    'legacy': 'legal',
#    'modern': 'legal',
#    'vintage': 'legal'},
#   'id': 'yamabushis-flame',
#   'name': "Yamabushi's Flame",
#   'store_url': 'http://store.tcgplayer.com/magic/champions-of-kamigawa/yamabushis-flame?partner=DECKBREW',
#   'text': "Yamabushi's Flame deals 3 damage to target creature or player. If a creature dealt damage this way would die this turn, exile it instead.",
#   'types': ['instant'],
#   'url': 'https://api.deckbrew.com/mtg/cards/yamabushis-flame'}]

# %% [markdown]
# ## DeckBrew API
# The DeckBrew api works, but it won't be supported after May 2018. They recommended Scryfall.

# %%
page_number = 0
modern_legal_cards = []
while True:
    response = requests.get('https://api.deckbrew.com/mtg/cards?format=modern&page={}'.format(page_number))
    
    if response.status_code != 200:
        print('Bad status code: {}'.format(response.status_code))
        break
    cards = json.loads(response.text)
    
    if cards == []:
        print('Empty page on page #{}'.format(page_number))
        break
        
    modern_legal_cards.append(cards)
    page_number += 1
    break

# %% [markdown]
# # Scryfall API
# Scryfall seems to work very well. [scryfall api](https://scryfall.com/docs/api)

# %%
response = requests.get('https://api.scryfall.com/cards/search?q=f:modern', 
                        headers={'User-Agent': 'Getting modern legal cards'})

response.status_code
# Out:
# 200

# %%
response_json = json.loads(response.text)

# %%
total_pages = 0
url = 'https://api.scryfall.com/cards/search?q=format:modern'
modern_legal_cards_scryfall = []
while True:
    response = requests.get(url, headers={'User-Agent': 'Getting modern legal cards'})
    
    if response.status_code != 200:
        print('Bad Status code on page #{}: {}'.format(response.status_code))
        break
        
    cards = json.loads(response.text)
    
    if not cards['has_more']:
        print('All done! {} pages recieved.'.format(total_pages))
        break
    
    modern_legal_cards_scryfall.append(cards['data'])
    total_pages += 1
    url = cards['next_page']
    
    time.sleep(0.05 + random.random())
    
    print('Page request #{} successful! Onto the next.'.format(total_pages))
# Out:
# Page request #1 successful! Onto the next.
# Page request #2 successful! Onto the next.
# Page request #3 successful! Onto the next.
# Page request #4 successful! Onto the next.
# Page request #5 successful! Onto the next.
# Page request #6 successful! Onto the next.
# Page request #7 successful! Onto the next.
# Page request #8 successful! Onto the next.
# Page request #9 successful! Onto the next.
# Page request #10 successful! Onto the next.
# Page request #11 successful! Onto the next.
# Page request #12 successful! Onto the next.
# Page request #13 successful! Onto the next.
# Page request #14 successful! Onto the next.
# Page request #15 successful! Onto the next.
# Page request #16 successful! Onto the next.
# Page request #17 successful! Onto the next.
# Page request #18 successful! Onto the next.
# Page request #19 successful! Onto the next.
# Page request #20 successful! Onto the next.
# Page request #21 successful! Onto the next.
# Page request #22 successful! Onto the next.
# Page request #23 successful! Onto the next.
# Page request #24 successful! Onto the next.
# Page request #25 successful! Onto the next.
# Page request #26 successful! Onto the next.
# Page request #27 successful! Onto the next.
# Page request #28 successful! Onto the next.
# Page request #29 successful! Onto the next.
# Page request #30 successful! Onto the next.
# Page request #31 successful! Onto the next.
# Page request #32 successful! Onto the next.
# Page request #33 successful! Onto the next.
# Page request #34 successful! Onto the next.
# Page request #35 successful! Onto the next.
# Page request #36 successful! Onto the next.
# Page request #37 successful! Onto the next.
# Page request #38 successful! Onto the next.
# Page request #39 successful! Onto the next.
# Page request #40 successful! Onto the next.
# Page request #41 successful! Onto the next.
# Page request #42 successful! Onto the next.
# Page request #43 successful! Onto the next.
# Page request #44 successful! Onto the next.
# Page request #45 successful! Onto the next.
# Page request #46 successful! Onto the next.
# Page request #47 successful! Onto the next.
# Page request #48 successful! Onto the next.
# Page request #49 successful! Onto the next.
# Page request #50 successful! Onto the next.
# Page request #51 successful! Onto the next.
# Page request #52 successful! Onto the next.
# Page request #53 successful! Onto the next.
# Page request #54 successful! Onto the next.
# Page request #55 successful! Onto the next.
# Page request #56 successful! Onto the next.
# Page request #57 successful! Onto the next.
# Page request #58 successful! Onto the next.
# Page request #59 successful! Onto the next.
# Page request #60 successful! Onto the next.
# Page request #61 successful! Onto the next.
# Page request #62 successful! Onto the next.
# Page request #63 successful! Onto the next.
# Page request #64 successful! Onto the next.
# All done! 64 pages recieved.

# %%
card_dict = {}
for page in modern_legal_cards_scryfall:
    for card in page:
        # 'id' is scryfalls unique ID
        card_dict[card['name']] = card['id']

# %%
card_dict['Lightning Bolt']
# Out:
# 'ccee0b4c-0cb0-4c0f-8ddc-bc74b8b97273'

# %% [markdown]
# # CSV Format
#
# I don't like the CSV format. It gives very little information that would be really useful for the future.

# %%
response = requests.get('https://api.scryfall.com/cards/search?q=format:modern&format=csv')

response.status_code
# Out:
# 200

# %%
response.text
# Out:
# 'multiverse_id,mtgo_id,set,collector_number,rarity,name,mana_cost,cmc,type_line,artist,usd,eur,tix,image_uri,scryfall_uri\n430847,64840,HOU,158,R,Abandoned Sarcophagus,{3},3.0,Artifact,Daarken,0.25,0.19,0.1,https://img.scryfall.com/cards/large/en/hou/158.jpg?1508728404,https://scryfall.com/card/hou/158\n414412,61408,EMN,115,U,Abandon Reason,{2}{R},3.0,Instant,Josh Hass,0.18,0.02,0.01,https://img.scryfall.com/cards/large/en/emn/115.jpg?1509843896,https://scryfall.com/card/emn/115\n409626,,DDQ,50,U,Abattoir Ghoul,{3}{B},4.0,Creature â\x80\x94 Zombie,Volkan Baga,0.16,0.04,,https://img.scryfall.com/cards/large/en/ddq/50.jpg?1509842399,https://scryfall.com/card/ddq/50\n235595,42612,ISD,1,C,Abbey Griffin,{3}{W},4.0,Creature â\x80\x94 Griffin,Jaime Jones,0.12,0.03,0.02,https://img.scryfall.com/cards/large/en/isd/1.jpg?1512049208,https://scryfall.com/card/isd/1\n398411,58042,ORI,127,R,Abbot of Keral Keep,{1}{R},2.0,Creature â\x80\x94 Human Monk,Deruchenko Alexander,0.69,0.95,0.12,https://img.scryfall.com/cards/large/en/ori/127.jpg?1509840356,https://scryfall.com/card/ori/127\n409790,59886,SOI,49,U,Aberrant Researcher // Perfected Form,{3}{U},4.0,Creature â\x80\x94 Human Insect // Creature â\x80\x94 Insect Horror,Nils Hamm,0.2,0.04,0.01,https://img.scryfall.com/cards/large/en/soi/49a.jpg?1509844963,https://scryfall.com/card/soi/49\n373661,50400,THS,75,R,Abhorrent Overlord,{5}{B}{B},7.0,Creature â\x80\x94 Demon,Slawomir Maniak,0.25,0.15,0.01,https://img.scryfall.com/cards/large/en/ths/75.jpg?1510051121,https://scryfall.com/card/ths/75\n386463,54416,KTK,159,C,Abomination of Gudul,{3}{B}{G}{U},6.0,Creature â\x80\x94 Horror,Erica Yang,0.12,0.02,0.01,https://img.scryfall.com/cards/large/en/ktk/159.jpg?1509841263,https://scryfall.com/card/ktk/159\n430772,64650,HOU,83,U,Abrade,{1}{R},2.0,Instant,Jonas De Ro,1.39,1.16,0.96,https://img.scryfall.com/cards/large/en/hou/83.jpg?1508726969,https://scryfall.com/card/hou/83\n425971,63379,MM3,146,R,Abrupt Decay,{B}{G},2.0,Instant,Svetlin Velinov,3.64,4.4,3.08,https://img.scryfall.com/cards/large/en/mm3/146.jpg?1512264332,https://scryfall.com/card/mm3/146\n96953,23777,GPT,1,C,Absolver Thrull,{3}{W},4.0,Creature â\x80\x94 Thrull Cleric,Rob Alexander,0.12,0.04,0.01,https://img.scryfall.com/cards/large/en/gpt/1.jpg?1510050345,https://scryfall.com/card/gpt/1\n416883,,CN2,126,C,Absorb Vis,{6}{B},7.0,Sorcery,Brandon Kitkouski,0.13,0.01,,https://img.scryfall.com/cards/large/en/cn2/126.jpg?1509842599,https://scryfall.com/card/cn2/126\n407550,59391,OGW,40,C,Abstruse Interference,{2}{U},3.0,Instant,Igor Kieryluk,0.12,0.02,0.01,https://img.scryfall.com/cards/large/en/ogw/40.jpg?1509846762,https://scryfall.com/card/ogw/40\n194371,38093,SOM,1,U,Abuna Acolyte,{1}{W},2.0,Creature â\x80\x94 Cat Cleric,Igor Kieryluk,0.17,0.03,0.01,https://img.scryfall.com/cards/large/en/som/1.jpg?1510060046,https://scryfall.com/card/som/1\n50164,20678,5DN,1,C,Abuna\'s Chant,{3}{W},4.0,Instant,John Matson,0.12,0.01,0.04,https://img.scryfall.com/cards/large/en/5dn/1.jpg?1510050613,https://scryfall.com/card/5dn/1\n433077,,C17,145,R,Abundance,{2}{G}{G},4.0,Enchantment,Rebecca Guay,0.25,0.23,,https://img.scryfall.com/cards/large/en/c17/145.jpg?1508811395,https://scryfall.com/card/c17/145\n413698,60755,EMA,156,C,Abundant Growth,{G},1.0,Enchantment â\x80\x94 Aura,Vincent Proce,0.17,0.13,0.06,https://img.scryfall.com/cards/large/en/ema/156.jpg?1509843674,https://scryfall.com/card/ema/156\n414290,61364,EMN,1,U,Abundant Maw,{8},8.0,Creature â\x80\x94 Eldrazi Leech,Greg Staples,0.18,0.03,0.01,https://img.scryfall.com/cards/large/en/emn/1.jpg?1509844144,https://scryfall.com/card/emn/1\n96858,23667,GPT,43,R,Abyssal Nocturnus,{1}{B}{B},3.0,Creature â\x80\x94 Horror,Jon Foster,0.69,0.51,0.01,https://img.scryfall.com/cards/large/en/gpt/43.jpg?1510050294,https://scryfall.com/card/gpt/43\n438644,66035,IMA,78,R,Abyssal Persecutor,{2}{B}{B},4.0,Creature â\x80\x94 Demon,Chippy,0.39,0.37,0.1,https://img.scryfall.com/cards/large/en/ima/78.jpg?1511920013,https ...

# %%
from io import StringIO

# %%
TESTDATA=StringIO(response.text)

df = pd.read_csv(TESTDATA, sep=",")

# %%
df.set_index(keys='multiverse_id', inplace=True)

# %%
df
# Out:
#                mtgo_id  set  collector_number rarity  \
# multiverse_id
# 430847         64840.0  HOU               158      R
# 414412         61408.0  EMN               115      U
# 409626             NaN  DDQ                50      U
# 235595         42612.0  ISD                 1      C
# 398411         58042.0  ORI               127      R
# 409790         59886.0  SOI                49      U
# 373661         50400.0  THS                75      R
# 386463         54416.0  KTK               159      C
# 430772         64650.0  HOU                83      U
# 425971         63379.0  MM3               146      R
# 96953          23777.0  GPT                 1      C
# 416883             NaN  CN2               126      C
# 407550         59391.0  OGW                40      C
# 194371         38093.0  SOM                 1      U
# 50164          20678.0  5DN                 1      C
# 433077             NaN  C17               145      R
# 413698         60755.0  EMA               156      C
# 414290         61364.0  EMN                 1      U
# 96858          23667.0  GPT                43      R
# 438644         66035.0  IMA                78      R
# 425884         63523.0  MM3                59      U
# 391781         55584.0  FRF                 2      C
# 386464         54426.0  KTK               160      R
# 386465         54060.0  KTK               215      C
# 438568         65883.0  IMA                 2      U
# 391782         55546.0  FRF               119      U
# 420794             NaN  C16               177      U
# 438569         65885.0  IMA                 3      U
# 386469         54136.0  KTK               162      C
# 391783         55534.0  FRF               120      U
# ...                ...  ...               ...    ...
# 409950         59752.0  SOI               193      C
# 394487         56288.0  DTK               171      C
# 438570         65887.0  IMA                 4      C
# 391786         55434.0  FRF               121      C
# 394488         55928.0  DTK               172      U
# 386472         54020.0  KTK                96      C
# 423672         62595.0  AER                 5      U
# 435197         65102.0  XLN                45      U
# 413370         60500.0  W16                 4      U
# 370680         49245.0  M14                 1      M
# 205957         37138.0  M11                 1      M
# 380367         52134.0  JOU               145      M
# 425695         63028.0  AER               188      R
# 405121             NaN  C15                57      R
# 425694         63014.0  AER               187      U
# 249398         42162.0  DDH                22      C
# 380368         52202.0  JOU                 2      C
# 438571         65889.0  IMA                 5      U
# 382211             NaN  CNS                66      C
# 383180         53504.0  M15                 1      M
# 423794         62831.0  AER               127      M
# 425692         63020.0  AER               185      M
# 266299         42174.0  DDH                 1      M
# 75277          21351.0  CHK               151      C
# 74428          21701.0  BOK                91      C
# 393941         28927.0  EVG                33      U
# 74393          22070.0  SOK                92      C
# 78694          21237.0  CHK               153      R
# 74596          21835.0  BOK                92      U
# 77919          21493.0  CHK               154      C
#
#                                                    name     mana_cost  cmc  \
# multiverse_id
# 430847                            Abandoned Sarcophagus           {3}  3.0
# 414412                                   Abandon Reason        {2}{R}  3.0
# 409626                                   Abattoir Ghoul        {3}{B}  4.0
# 235595                                    Abbey Griffin        {3}{W}  4.0
# 398411                              Abbot of Keral Keep        {1}{R}  2.0
# 409790            Aberrant Researcher // Perfected Form        {3}{U}  4.0
# 373661                               Abhorrent Overlord     {5}{B}{B}  7.0
# 386463                             Abomination of Gudul  {3}{B}{G}{U}  6.0
# 430772                                           Abrade        {1}{R}  2.0
# 425971                                     Abrupt Decay        {B}{G}  2.0
# 96953                                   Absolver Thrull        {3}{W}  4.0
# 416883                                       Absorb Vis        {6}{B}  7.0
# 407550                            Abstruse Interference        {2}{U}  3.0
# 194371                                    Abuna Acolyte        {1}{W}  2.0
# 50164                                     Abuna's Chant        {3}{W}  4.0
# 433077                                        Abundance     {2}{G}{G}  4.0
# 413698                                  Abundant Growth           {G}  1.0
# 414290                                     Abundant Maw           {8}  8.0
# 96858                                 Abyssal Nocturnus     {1}{B}{B}  3.0
# 438644                               Abyssal Persecutor     {2}{B}{B}  4.0
# 425884                                  Abyssal Specter     {2}{B}{B}  4.0
# 391781                                  Abzan Advantage        {1}{W}  2.0
# 386464                                 Abzan Ascendancy     {W}{B}{G}  3.0
# 386465                                     Abzan Banner           {3}  3.0
# 438568                              Abzan Battle Priest        {3}{W}  4.0
# 391782                                Abzan Beastmaster        {2}{G}  3.0
# 420794                                      Abzan Charm     {W}{B}{G}  3.0
# 438569                                   Abzan Falconer        {2}{W}  3.0
# 386469                                      Abzan Guide  {3}{W}{B}{G}  6.0
# 391783                                  Abzan Kin-Guard        {3}{G}  4.0
# ...                                                 ...           ...  ...
# 409950                                         Aim High        {1}{G}  2.0
# 394487                                Ainok Artillerist        {2}{G}  3.0
# 438570                                   Ainok Bond-Kin        {1}{W}  2.0
# 391786                                      Ainok Guide        {1}{G}  2.0
# 394488                                Ainok Survivalist        {1}{G}  2.0
# 386472                                    Ainok Tracker        {5}{R}  6.0
# 423672                                Airdrop Aeronauts     {3}{W}{W}  5.0
# 435197                                    Air Elemental     {3}{U}{U}  5.0
# 413370                                      Air Servant        {4}{U}  5.0
# 370680                       Ajani, Caller of the Pride     {1}{W}{W}  3.0
# 205957                                   Ajani Goldmane     {2}{W}{W}  4.0
# 380367                          Ajani, Mentor of Heroes     {3}{G}{W}  5.0
# 425695                                      Ajani's Aid     {2}{G}{W}  4.0
# 405121                                   Ajani's Chosen     {2}{W}{W}  4.0
# 425694                                  Ajani's Comrade        {1}{G}  2.0
# 249398                                   Ajani's Mantra        {1}{W}  2.0
# 380368                                 Ajani's Presence           {W}  1.0
# 438571                                Ajani's Pridemate        {1}{W}  2.0
# 382211                               Ajani's Sunstriker        {W}{W}  2.0
# 383180                                  Ajani Steadfast        {3}{W}  4.0
# 423794                                 Ajani Unyielding     {4}{G}{W}  6.0
# 425692                         Ajani, Valiant Protector     {4}{G}{W}  6.0
# 266299                                   Ajani Vengeant     {2}{R}{W}  4.0
# 75277                                  Akki Avalanchers           {R}  1.0
# 74428                              Akki Blizzard-Herder        {1}{R}  2.0
# 393941                                 Akki Coalflinger     {1}{R}{R}  3.0
# 74393                                  Akki Drillmaster        {2}{R}  3.0
# 78694          Akki Lavarunner // Tok-Tok, Volcano Born        {3}{R}  4.0
# 74596                                       Akki Raider        {1}{R}  2.0
# 77919                                  Akki Rockspeaker        {1}{R}  2.0
#
#                                                        type_line  \
# multiverse_id
# 430847                                                  Artifact
# 414412                                                   Instant
# 409626                                       Creature â Zombie
# 235595                                      Creature â Griffin
# 398411                                   Creature â Human Monk
# 409790         Creature â Human Insect // Creature â Inse...
# 373661                                        Creature â Demon
# 386463                                       Creature â Horror
# 430772                                                   Instant
# 425971                                                   Instant
# 96953                                 Creature â Thrull Cleric
# 416883                                                   Sorcery
# 407550                                                   Instant
# 194371                                   Creature â Cat Cleric
# 50164                                                    Instant
# 433077                                               Enchantment
# 413698                                      Enchantment â Aura
# 414290                                Creature â Eldrazi Leech
# 96858                                        Creature â Horror
# 438644                                        Creature â Demon
# 425884                                      Creature â Specter
# 391781                                                   Instant
# 386464                                               Enchantment
# 386465                                                  Artifact
# 438568                                 Creature â Human Cleric
# 391782                                 Creature â Hound Shaman
# 420794                                                   Instant
# 438569                                Creature â Human Soldier
# 386469                                Creature â Human Warrior
# 391783                                Creature â Human Warrior
# ...                                                          ...
# 409950                                                   Instant
# 394487                                 Creature â Hound Archer
# 438570                                Creature â Hound Soldier
# 391786                                  Creature â Hound Scout
# 394488                                 Creature â Hound Shaman
# 386472                                  Creature â Hound Scout
# 423672                                  Creature â Dwarf Scout
# 435197                                    Creature â Elemental
# 413370                                    Creature â Elemental
# 370680                          Legendary Planeswalker â Ajani
# 205957                          Legendary Planeswalker â Ajani
# 380367                          Legendary Planeswalker â Ajani
# 425695                                               Enchantment
# 405121                                  Creature â Cat Soldier
# 425694                                  Creature â Elf Soldier
# 249398                                               Enchantment
# 380368                                                   Instant
# 438571                                  Creature â Cat Soldier
# 382211                                   Creature â Cat Cleric
# 383180                          Legendary Planeswalker â Ajani
# 423794                          Legendary Planeswalker â Ajani
# 425692                          Legendary Planeswalker â Ajani
# 266299                          Legendary Planeswalker â Ajani
# 75277                                Creature â Goblin Warrior
# 74428                                 Creature â Goblin Shaman
# 393941                                Creature â Goblin Shaman
# 74393                                 Creature â Goblin Shaman
# 78694          Creature â Goblin Warrior // Legendary Creat...
# 74596                                Creature â Goblin Warrior
# 77919                                 Creature â Goblin Shaman
#
#                              artist    usd    eur   tix  \
# multiverse_id
# 430847                      Daarken   0.25   0.19  0.10
# 414412                    Josh Hass   0.18   0.02  0.01
# 409626                  Volkan Baga   0.16   0.04   NaN
# 235595                  Jaime Jones   0.12   0.03  0.02
# 398411         Deruchenko Alexander   0.69   0.95  0.12
# 409790                    Nils Hamm   0.20   0.04  0.01
# 373661              Slawomir Maniak   0.25   0.15  0.01
# 386463                   Erica Yang   0.12   0.02  0.01
# 430772                  Jonas De Ro   1.39   1.16  0.96
# 425971              Svetlin Velinov   3.64   4.40  3.08
# 96953                 Rob Alexander   0.12   0.04  0.01
# 416883            Brandon Kitkouski   0.13   0.01   NaN
# 407550                Igor Kieryluk   0.12   0.02  0.01
# 194371                Igor Kieryluk   0.17   0.03  0.01
# 50164                   John Matson   0.12   0.01  0.04
# 433077                 Rebecca Guay   0.25   0.23   NaN
# 413698                Vincent Proce   0.17   0.13  0.06
# 414290                 Greg Staples   0.18   0.03  0.01
# 96858                    Jon Foster   0.69   0.51  0.01
# 438644                       Chippy   0.39   0.37  0.10
# 425884                      Daarken   0.18   0.02  0.01
# 391781                Winona Nelson   0.12   0.02  0.01
# 386464                 Mark Winters   0.25   0.17  0.01
# 386465             Daniel Ljunggren   0.12   0.05  0.01
# 438568                   Chris Rahn   0.14   0.10  0.03
# 391782                Winona Nelson   0.19   0.08  0.02
# 420794              Mathias Kollros   0.22   0.14   NaN
# 438569              Steven Belledin   0.14   0.07  0.01
# 386469               Steve Prescott   0.12   0.02  0.01
# 391783             Craig J Spearing   0.19   0.02  0.01
# ...                             ...    ...    ...   ...
# 409950               Steve Prescott   0.12   0.03  0.01
# 394487                  James Paick   0.12   0.03  0.01
# 438570                   Chris Rahn   0.10   0.03  0.01
# 391786               Lucas Graciano   0.13   0.03  0.01
# 394488             Craig J Spearing   0.20   0.10  0.02
# 386472                 Evan Shipard   0.12   0.02  0.01
# 423672               Greg Opalinski   0.19   0.02  0.01
# 435197             Tomasz Jedruszek   0.16   0.02  0.01
# 413370              Lars Grant-West   0.12   0.09  0.05
# 370680         D. Alexander Gregory   5.18   4.94  0.55
# 205957               Aleksi Briclot   7.11   4.57  0.19
# 380367                 Aaron Miller  13.34  10.78  0.44
# 425695               Terese Nielsen   0.25   0.14  1.50
# 405121               Wayne Reynolds   0.35   0.23   NaN
# 425694                  James Ryman   0.22   0.14  0.77
# 249398                  James Paick   0.25   0.11  0.68
# 380368             Raymond Swanland   0.15   0.07  0.02
# 438571              Svetlin Velinov   0.22   0.20  0.04
# 382211                 Matt Stewart   0.13   0.04   NaN
# 383180                   Chris Rahn   8.90   8.98  0.47
# 423794                Kieran Yanner   2.60   2.10  0.64
# 425692              Anna Steinbauer   3.49   5.02  4.00
# 266299                         Izzy   6.08   3.78  5.84
# 75277                 Matt Thompson   0.13   0.03  0.01
# 74428                  Pete Venters   0.13   0.04  0.01
# 393941                      Nottsuo   0.20    NaN  0.03
# 74393                  Alan Pollack   0.13   0.05  0.02
# 78694                  Matt Cavotta   0.35   0.16  0.01
# 74596             Martina Pilcerova   0.20   0.02  0.02
# 77919                  David Martin   0.13   0.03  0.01
#
#                                                        image_uri  \
# multiverse_id
# 430847         https://img.scryfall.com/cards/large/en/hou/15...
# 414412         https://img.scryfall.com/cards/large/en/emn/11...
# 409626         https://img.scryfall.com/cards/large/en/ddq/50...
# 235595         https://img.scryfall.com/cards/large/en/isd/1....
# 398411         https://img.scryfall.com/cards/large/en/ori/12...
# 409790         https://img.scryfall.com/cards/large/en/soi/49...
# 373661         https://img.scryfall.com/cards/large/en/ths/75...
# 386463         https://img.scryfall.com/cards/large/en/ktk/15...
# 430772         https://img.scryfall.com/cards/large/en/hou/83...
# 425971         https://img.scryfall.com/cards/large/en/mm3/14...
# 96953          https://img.scryfall.com/cards/large/en/gpt/1....
# 416883         https://img.scryfall.com/cards/large/en/cn2/12...
# 407550         https://img.scryfall.com/cards/large/en/ogw/40...
# 194371         https://img.scryfall.com/cards/large/en/som/1....
# 50164          https://img.scryfall.com/cards/large/en/5dn/1....
# 433077         https://img.scryfall.com/cards/large/en/c17/14...
# 413698         https://img.scryfall.com/cards/large/en/ema/15...
# 414290         https://img.scryfall.com/cards/large/en/emn/1....
# 96858          https://img.scryfall.com/cards/large/en/gpt/43...
# 438644         https://img.scryfall.com/cards/large/en/ima/78...
# 425884         https://img.scryfall.com/cards/large/en/mm3/59...
# 391781         https://img.scryfall.com/cards/large/en/frf/2....
# 386464         https://img.scryfall.com/cards/large/en/ktk/16...
# 386465         https://img.scryfall.com/cards/large/en/ktk/21...
# 438568         https://img.scryfall.com/cards/large/en/ima/2....
# 391782         https://img.scryfall.com/cards/large/en/frf/11...
# 420794         https://img.scryfall.com/cards/large/en/c16/17...
# 438569         https://img.scryfall.com/cards/large/en/ima/3....
# 386469         https://img.scryfall.com/cards/large/en/ktk/16...
# 391783         https://img.scryfall.com/cards/large/en/frf/12...
# ...                                                          ...
# 409950         https://img.scryfall.com/cards/large/en/soi/19...
# 394487         https://img.scryfall.com/cards/large/en/dtk/17...
# 438570         https://img.scryfall.com/cards/large/en/ima/4....
# 391786         https://img.scryfall.com/cards/large/en/frf/12...
# 394488         https://img.scryfall.com/cards/large/en/dtk/17...
# 386472         https://img.scryfall.com/cards/large/en/ktk/96...
# 423672         https://img.scryfall.com/cards/large/en/aer/5....
# 435197         https://img.scryfall.com/cards/large/en/xln/45...
# 413370         https://img.scryfall.com/cards/large/en/w16/4....
# 370680         https://img.scryfall.com/cards/large/en/m14/1....
# 205957         https://img.scryfall.com/cards/large/en/m11/1....
# 380367         https://img.scryfall.com/cards/large/en/jou/14...
# 425695         https://img.scryfall.com/cards/large/en/aer/18...
# 405121         https://img.scryfall.com/cards/large/en/c15/57...
# 425694         https://img.scryfall.com/cards/large/en/aer/18...
# 249398         https://img.scryfall.com/cards/large/en/ddh/22...
# 380368         https://img.scryfall.com/cards/large/en/jou/2....
# 438571         https://img.scryfall.com/cards/large/en/ima/5....
# 382211         https://img.scryfall.com/cards/large/en/cns/66...
# 383180         https://img.scryfall.com/cards/large/en/m15/1....
# 423794         https://img.scryfall.com/cards/large/en/aer/12...
# 425692         https://img.scryfall.com/cards/large/en/aer/18...
# 266299         https://img.scryfall.com/cards/large/en/ddh/1....
# 75277          https://img.scryfall.com/cards/large/en/chk/15...
# 74428          https://img.scryfall.com/cards/large/en/bok/91...
# 393941         https://img.scryfall.com/cards/large/en/evg/33...
# 74393          https://img.scryfall.com/cards/large/en/sok/92...
# 78694          https://img.scryfall.com/cards/large/en/chk/15...
# 74596          https://img.scryfall.com/cards/large/en/bok/92...
# 77919          https://img.scryfall.com/cards/large/en/chk/15...
#
#                                     scryfall_uri
# multiverse_id
# 430847         https://scryfall.com/card/hou/158
# 414412         https://scryfall.com/card/emn/115
# 409626          https://scryfall.com/card/ddq/50
# 235595           https://scryfall.com/card/isd/1
# 398411         https://scryfall.com/card/ori/127
# 409790          https://scryfall.com/card/soi/49
# 373661          https://scryfall.com/card/ths/75
# 386463         https://scryfall.com/card/ktk/159
# 430772          https://scryfall.com/card/hou/83
# 425971         https://scryfall.com/card/mm3/146
# 96953            https://scryfall.com/card/gpt/1
# 416883         https://scryfall.com/card/cn2/126
# 407550          https://scryfall.com/card/ogw/40
# 194371           https://scryfall.com/card/som/1
# 50164            https://scryfall.com/card/5dn/1
# 433077         https://scryfall.com/card/c17/145
# 413698         https://scryfall.com/card/ema/156
# 414290           https://scryfall.com/card/emn/1
# 96858           https://scryfall.com/card/gpt/43
# 438644          https://scryfall.com/card/ima/78
# 425884          https://scryfall.com/card/mm3/59
# 391781           https://scryfall.com/card/frf/2
# 386464         https://scryfall.com/card/ktk/160
# 386465         https://scryfall.com/card/ktk/215
# 438568           https://scryfall.com/card/ima/2
# 391782         https://scryfall.com/card/frf/119
# 420794         https://scryfall.com/card/c16/177
# 438569           https://scryfall.com/card/ima/3
# 386469         https://scryfall.com/card/ktk/162
# 391783         https://scryfall.com/card/frf/120
# ...                                          ...
# 409950         https://scryfall.com/card/soi/193
# 394487         https://scryfall.com/card/dtk/171
# 438570           https://scryfall.com/card/ima/4
# 391786         https://scryfall.com/card/frf/121
# 394488         https://scryfall.com/card/dtk/172
# 386472          https://scryfall.com/card/ktk/96
# 423672           https://scryfall.com/card/aer/5
# 435197          https://scryfall.com/card/xln/45
# 413370           https://scryfall.com/card/w16/4
# 370680           https://scryfall.com/card/m14/1
# 205957           https://scryfall.com/card/m11/1
# 380367         https://scryfall.com/card/jou/145
# 425695         https://scryfall.com/card/aer/188
# 405121          https://scryfall.com/card/c15/57
# 425694         https://scryfall.com/card/aer/187
# 249398          https://scryfall.com/card/ddh/22
# 380368           https://scryfall.com/card/jou/2
# 438571           https://scryfall.com/card/ima/5
# 382211          https://scryfall.com/card/cns/66
# 383180           https://scryfall.com/card/m15/1
# 423794         https://scryfall.com/card/aer/127
# 425692         https://scryfall.com/card/aer/185
# 266299           https://scryfall.com/card/ddh/1
# 75277          https://scryfall.com/card/chk/151
# 74428           https://scryfall.com/card/bok/91
# 393941          https://scryfall.com/card/evg/33
# 74393           https://scryfall.com/card/sok/92
# 78694          https://scryfall.com/card/chk/153
# 74596           https://scryfall.com/card/bok/92
# 77919          https://scryfall.com/card/chk/154
#
# [175 rows x 14 columns]

# %%
response.
